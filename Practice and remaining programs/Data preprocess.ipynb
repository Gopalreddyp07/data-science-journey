# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("titanics.csv")
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.heatmap(df.isna(),cmap="coolwarm")
plt.show()

# %%
# filling null values using the pandas
# df["Age"]=df["Age"].fillna(df["Age"].mean())

# %%
# filling the null values using the simpleimputation technique
impute=SimpleImputer(strategy="most_frequent")#strategy=mean,most_frequent,median,default
df["Age"]=impute.fit_transform(df[["Age"]])

# %%
impute=SimpleImputer(strategy="most_frequent")
df[["Embarked"]]=impute.fit_transform(df[["Embarked"]])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# drop the cabin column which contain the most null values
df.drop("Cabin",axis=1,inplace=True)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  24.0      0
# ...

# %%
# converting the ages into int values
df["Age"]=df["Age"].astype(int)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             71
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Embarked         3
# dtype: int64

# %%
ax=sns.barplot(x="Sex",y="Survived",data=df,hue="Pclass",errorbar=None)
for containers in ax.containers:
    ax.bar_label(containers,fmt="%.2f")
plt.show()

# %%
# fig=plt.figure(dpi=300)
ax=sns.countplot(x="Sex", hue="Survived",data=df)
plt.title("No of male and Female survival rate of the titanic ship")
for container in ax.containers:
    ax.bar_label(container)
# plt.tight_layout()
# plt.grid()
plt.show()

# %%
sns.histplot(x="Age",data=df,bins=10,hue="Sex",palette=["red","green"],kde=True)
plt.show()

# %%
# Passenger id and their age and their Sex
plt.title("Passenger id and their age and their Sex")
sns.scatterplot(x="Age",y="PassengerId",hue="Sex",data=df)
plt.show()
print("There we concluded the most for the people age group between 20 t0 30")
# Out:
# There we concluded the most for the people age group between 20 t0 30

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# Encoding using pandas 
df["Sex"]=df["Sex"].replace({"female":0,"male":1})
df
# Out:
# C:\Users\gopal\AppData\Local\Temp\ipykernel_8292\3396802631.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Sex"]=df["Sex"].replace({"female":0,"male":1})
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1   22      1
# ...

# %%
# encoding using the sklearn
#LabelEncoder,OneHotEncoder,OrdinalEncoder
# from sklearn.preprocessing import OneHotEncoder
# encoder=OneHotEncoder(sparse_output=False)
# encoded=encoder.fit_transform(df[["Embarked"]])
# columns=encoder.get_feature_names_out()
# df_encode=pd.DataFrame(encoded,columns=columns)
# df=pd.concat([df,df_encode],axis=1)

# %%
# from sklearn.preprocessing import OrdinalEncoder
# encoder=OrdinalEncoder(categories=[["S","Q","C"]])
# df[["Embarked"]]=encoder.fit_transform(df[["Embarked"]])

# %%
# df.drop("Embarked",axis=1)

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df["Ticket"].nunique()
# Out:
# 681

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0   38      1      0
# 2                             Heikkinen, Miss. Laina    0   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0   35      1      0
# 4                           Allen, Mr. William Henry    1   35      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df["Embarked"]=encoder.fit_transform(df["Embarked"])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0   38      1
# 2                               Heikkinen, Miss. Laina    0   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0   35      1
# 4                             Allen, Mr. William Henry    1   35      0
# ..                                                 ...  ...  ...    ...
# ...

# %%
df.drop(df[["PassengerId","Name","Ticket"]],axis=1,inplace=True)

# %%
df["Age"].nunique()
# Out:
# 71

# %%
df
# Out:
#      Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1   22      1      0   7.2500         2
# 1           1       1    0   38      1      0  71.2833         0
# 2           1       3    0   26      0      0   7.9250         2
# 3           1       1    0   35      1      0  53.1000         2
# 4           0       3    1   35      0      0   8.0500         2
# ..        ...     ...  ...  ...    ...    ...      ...       ...
# 886         0       2    1   27      0      0  13.0000         2
# 887         1       1    0   19      0      0  30.0000         2
# 888         0       3    0   24      1      2  23.4500         2
# 889         1       1    1   26      0      0  30.0000         0
# 890         0       3    1   32      0      0   7.7500         1
#
# [891 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()
df_minmax=pd.DataFrame(scale.fit_transform(df),columns=df.columns)

# %%
df_minmax.head(10)
# Out:
#    Survived  Pclass  Sex     Age  SibSp     Parch      Fare  Embarked
# 0       0.0     1.0  1.0  0.2750  0.125  0.000000  0.014151       1.0
# 1       1.0     0.0  0.0  0.4750  0.125  0.000000  0.139136       0.0
# 2       1.0     1.0  0.0  0.3250  0.000  0.000000  0.015469       1.0
# 3       1.0     0.0  0.0  0.4375  0.125  0.000000  0.103644       1.0
# 4       0.0     1.0  1.0  0.4375  0.000  0.000000  0.015713       1.0
# 5       0.0     1.0  1.0  0.3000  0.000  0.000000  0.016510       0.5
# 6       0.0     0.0  1.0  0.6750  0.000  0.000000  0.101229       1.0
# 7       0.0     1.0  1.0  0.0250  0.375  0.166667  0.041136       1.0
# 8       1.0     1.0  0.0  0.3375  0.000  0.333333  0.021731       1.0
# 9       1.0     0.5  0.0  0.1750  0.125  0.000000  0.058694       0.0

# %%
df_minmax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    float64
#  1   Pclass    891 non-null    float64
#  2   Sex       891 non-null    float64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    float64
#  5   Parch     891 non-null    float64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    float64
# dtypes: float64(8)
# memory usage: 55.8 KB

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
df_standard=pd.DataFrame(scale.fit_transform(df),columns=df.columns)
df_standard
# Out:
#      Survived    Pclass       Sex       Age     SibSp     Parch      Fare  \
# 0   -0.789272  0.827377  0.737695 -0.496308  0.432793 -0.473674 -0.502445
# 1    1.266990 -1.566107 -1.355574  0.715850  0.432793 -0.473674  0.786845
# 2    1.266990  0.827377 -1.355574 -0.193268 -0.474545 -0.473674 -0.488854
# 3    1.266990 -1.566107 -1.355574  0.488570  0.432793 -0.473674  0.420730
# 4   -0.789272  0.827377  0.737695  0.488570 -0.474545 -0.473674 -0.486337
# ..        ...       ...       ...       ...       ...       ...       ...
# 886 -0.789272 -0.369365  0.737695 -0.117509 -0.474545 -0.473674 -0.386671
# 887  1.266990 -1.566107 -1.355574 -0.723588 -0.474545 -0.473674 -0.044381
# 888 -0.789272  0.827377 -1.355574 -0.344788  0.432793  2.008933 -0.176263
# 889  1.266990 -1.566107  0.737695 -0.193268 -0.474545 -0.473674 -0.044381
# 890 -0.789272  0.827377  0.737695  0.261291 -0.474545 -0.473674 -0.492378
#
#      Embarked
# 0    0.585954
# 1   -1.942303
# 2    0.585954
# 3    0.585954
# ...

# %%
fig=plt.figure(dpi=300)
sns.boxplot(data=df_standard)
plt.show()

# %%
# fig=plt.figure(dpi=300)
# sns.scatterplot(data=df_standard)
# plt.show()

# %%
from scipy.stats import zscore
df_standard["Age"]=zscore(df_standard["Age"])

# %%
Q1 = df_standard['Age'].quantile(0.25)
Q3 = df_standard['Age'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df_standard[(df_standard['Age'] < lower) & (df_standard['Age'] > upper)]
df_standard=df_standard.drop(outliers.index)

# %%
lower
# Out:
# -1.9736254592346494

# %%
upper
# Out:
# 1.965887918929613

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Sex, Age, SibSp, Parch, Fare, Embarked]
# Index: []

# %%
fig=plt.figure(dpi=200)
sns.boxplot(data=df_standard)
plt.show()

# %%
outlier=df_standard[df_standard["Age"].abs()>3]

# %%
# df_standard['Age'] = np.log1p(df['Age'])  # log(1 + x) handles 0s

# %%
fig=plt.figure(dpi=300)
sns.histplot(data=df_standard["Age"],bins=10,kde=True)
plt.show()

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Sex, Age, SibSp, Parch, Fare, Embarked]
# Index: []

# %%
from scipy.stats import zscore
df_standard["Fare"]=zscore(df_standard["Fare"])

# %%
out=df_standard[df_standard["Fare"].abs()>3]
out
df_standard.drop(out.index,inplace=True)

# %%
df_standard.head(10)
# Out:
#    Survived    Pclass       Sex       Age     SibSp     Parch      Fare  \
# 0 -0.789272  0.827377  0.737695 -0.496308  0.432793 -0.473674 -0.502445
# 1  1.266990 -1.566107 -1.355574  0.715850  0.432793 -0.473674  0.786845
# 2  1.266990  0.827377 -1.355574 -0.193268 -0.474545 -0.473674 -0.488854
# 3  1.266990 -1.566107 -1.355574  0.488570  0.432793 -0.473674  0.420730
# 4 -0.789272  0.827377  0.737695  0.488570 -0.474545 -0.473674 -0.486337
# 5 -0.789272  0.827377  0.737695 -0.344788 -0.474545 -0.473674 -0.478116
# 6 -0.789272 -1.566107  0.737695  1.928008 -0.474545 -0.473674  0.395814
# 7 -0.789272  0.827377  0.737695 -2.011505  2.247470  0.767630 -0.224083
# 8  1.266990  0.827377 -1.355574 -0.117509 -0.474545  2.008933 -0.424256
# 9  1.266990 -0.369365 -1.355574 -1.102387  0.432793 -0.473674 -0.042956
#
#    Embarked
# 0  0.585954
# 1 -1.942303
# 2  0.585954
# 3  0.585954
# 4  0.585954
# 5 -0.678175
# 6  0.585954
# 7  0.585954
# 8  0.585954
# 9 -1.942303

# %%
Q1=df_standard["Fare"].quantile(0.25)
Q3=df_standard["Fare"].quantile(0.75)
IQR=Q3-Q1
lower=Q1-1.5*IQR
upper=Q3+1.5*IQR
outlier=df_standard[(df_standard["Fare"]>lower)|(df_standard["Fare"]<upper)]
df_standard=df.drop(outlier.index)

# %%
outlier
# Out:
#      Survived    Pclass       Sex       Age     SibSp     Parch      Fare  \
# 0   -0.789272  0.827377  0.737695 -0.496308  0.432793 -0.473674 -0.502445
# 1    1.266990 -1.566107 -1.355574  0.715850  0.432793 -0.473674  0.786845
# 2    1.266990  0.827377 -1.355574 -0.193268 -0.474545 -0.473674 -0.488854
# 3    1.266990 -1.566107 -1.355574  0.488570  0.432793 -0.473674  0.420730
# 4   -0.789272  0.827377  0.737695  0.488570 -0.474545 -0.473674 -0.486337
# ..        ...       ...       ...       ...       ...       ...       ...
# 886 -0.789272 -0.369365  0.737695 -0.117509 -0.474545 -0.473674 -0.386671
# 887  1.266990 -1.566107 -1.355574 -0.723588 -0.474545 -0.473674 -0.044381
# 888 -0.789272  0.827377 -1.355574 -0.344788  0.432793  2.008933 -0.176263
# 889  1.266990 -1.566107  0.737695 -0.193268 -0.474545 -0.473674 -0.044381
# 890 -0.789272  0.827377  0.737695  0.261291 -0.474545 -0.473674 -0.492378
#
#      Embarked
# 0    0.585954
# 1   -1.942303
# 2    0.585954
# 3    0.585954
# ...

# %%
fig=plt.figure(dpi=300)
sns.boxplot(data=outlier)
plt.show()

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=3)
df_pca=pd.DataFrame(pca.fit_transform(df_standard),columns=["data1","data2","data3"])

# %%
df_pca.head(10)
# Out:
#         data1      data2     data3
# 0  -16.554362 -11.145936  2.443508
# 1  -16.470204  -7.152991  2.435012
# 2  -31.912391  -5.752774 -0.951788
# 3  233.068035  -0.348984 -0.729757
# 4  -31.365830  20.219204 -0.775389
# 5  -17.192160 -12.108317  0.989763
# 6  -16.449186  -6.153944  2.443416
# 7  -67.863515  -1.979446 -0.394209
# 8  -51.523510  12.627420 -1.547374
# 9  -15.609012  33.915563  2.762969

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda=LDA(n_components=3)
df_lda=pd.DataFrame(pca.fit_transform(df_standard),columns=["data1","data2","data3"])
df_lda.head(10)
# Out:
#         data1      data2     data3
# 0  -16.554362 -11.145936  2.443508
# 1  -16.470204  -7.152991  2.435012
# 2  -31.912391  -5.752774 -0.951788
# 3  233.068035  -0.348984 -0.729757
# 4  -31.365830  20.219204 -0.775389
# 5  -17.192160 -12.108317  0.989763
# 6  -16.449186  -6.153944  2.443416
# 7  -67.863515  -1.979446 -0.394209
# 8  -51.523510  12.627420 -1.547374
# 9  -15.609012  33.915563  2.762969

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# selector = SelectKBest(score_func=f_classif, k=3)
# X_new = selector.fit_transform(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[146], line 3
#       1 from sklearn.feature_selection import SelectKBest, f_classif
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.2,random_state=10)
#       5 # selector = SelectKBest(score_func=f_classif, k=3)
#       6 # X_new = selector.fit_transform(X, y)
#
# NameError: name 'X' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# 1. Define the data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Feature: hours studied
y = np.array([50, 55, 65, 70, 75])           # Target: exam scores

# 2. Create and train the model
model = LinearRegression()
model.fit(X, y)

# 3. Make predictions
y_pred = model.predict(X)

# 4. Print model parameters
print(f"Intercept (β₀): {model.intercept_:.2f}")
print(f"Slope (β₁): {model.coef_[0]:.2f}")

# 5. Evaluate the model
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)
print(f"Mean Squared Error: {mse:.2f}")
print(f"R² Score: {r2:.2f}")

# 6. Visualize
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', linewidth=2, label='Regression Line')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.title('Linear Regression Example')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Intercept (β₀): 43.50
# Slope (β₁): 6.50
# Mean Squared Error: 1.50
# R² Score: 0.98
