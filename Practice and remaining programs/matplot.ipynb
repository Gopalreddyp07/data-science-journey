# %% [markdown]
# Here is a list of **Matplotlib built-in functions** in order, starting from **figure creation** to **plot customization**, **annotations**, and **saving the plot**.
#
# ---
#
# ### **1. Figure and Axes Management**
# These functions initialize and manage figures and subplots.
# - `plt.figure(figsize=(width, height), dpi=dpi_value)`: Creates a new figure with a specified size and resolution.
# - `fig, ax = plt.subplots(nrows, ncols, figsize=(width, height))`: Creates multiple subplots in a figure.
# - `plt.subplot(nrows, ncols, index)`: Creates a subplot in a grid layout.
# - `plt.tight_layout()`: Adjusts subplot spacing to prevent overlap.
#
# ---
#
# ### **2. Plotting Functions**
# These functions generate different types of plots.
# - `plt.plot(x, y, linestyle='', marker='', color='', label='')`: Creates a line plot.
# - `plt.scatter(x, y, s=marker_size, c=color, label='', alpha=opacity)`: Creates a scatter plot.
# - `plt.bar(x, height, width=bar_width, color='', label='', align='')`: Creates a bar chart.
# - `plt.barh(y, width, height=bar_height, color='', label='')`: Creates a horizontal bar chart.
# - `plt.hist(data, bins=number_of_bins, color='', edgecolor='', alpha=opacity)`: Plots a histogram.
# - `plt.boxplot(data, notch=False, vert=True, patch_artist=True)`: Creates a box plot.
# - `plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, explode=explode_values, shadow=True)`: Draws a pie chart.
#
# ---
#
# ### **3. Axis and Grid Customization**
# These functions modify the axes and add grid lines.
# - `plt.xlabel('X-axis label', fontsize=size, color=color)`: Sets the x-axis label.
# - `plt.ylabel('Y-axis label', fontsize=size, color=color)`: Sets the y-axis label.
# - `plt.title('Graph Title', fontsize=size, color=color, loc='left/right/center')`: Adds a title to the plot.
# - `plt.legend(loc='upper/lower left/right', fontsize=size, title='Legend Title')`: Adds a legend.
# - `plt.grid(True, linestyle='--', linewidth=width, alpha=opacity)`: Adds grid lines.
# - `plt.xticks(ticks, labels, rotation=angle, fontsize=size)`: Customizes x-axis tick labels.
# - `plt.yticks(ticks, labels, rotation=angle, fontsize=size)`: Customizes y-axis tick labels.
#
# ---
#
# ### **4. Axis Limits and Scaling**
# These functions adjust axis ranges and scales.
# - `plt.xlim(left=min_value, right=max_value)`: Sets x-axis limits.
# - `plt.ylim(bottom=min_value, top=max_value)`: Sets y-axis limits.
# - `plt.axis([xmin, xmax, ymin, ymax])`: Sets limits for both x and y axes.
# - `plt.xscale('linear/log/symlog/logit')`: Changes x-axis scale.
# - `plt.yscale('linear/log/symlog/logit')`: Changes y-axis scale.
#
# ---
#
# ### **5. Annotations and Text**
# These functions help in labeling data points.
# - `plt.text(x, y, 'Text', fontsize=size, color=color, ha='center/left/right', va='center/top/bottom')`: Adds text at a specific position.
# - `plt.annotate('Annotation', xy=(x, y), xytext=(x_offset, y_offset), arrowprops={'arrowstyle': '->'})`: Adds an annotation with an arrow.
#
# ---
#
# ### **6. Saving and Displaying the Plot**
# These functions control how the plot is saved or displayed.
# - `plt.savefig('filename.png', dpi=resolution, format='png/pdf/svg', bbox_inches='tight')`: Saves the figure.
# - `plt.show()`: Displays the plot.
#
# ---
#
# This list is structured in the order of usage, making it easy to follow when working with **Matplotlib**. Let me know if you need further clarification! 🚀

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import scipy as sci
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x=np.random.randint(20,30,size=20)
y=np.random.randint(10000,30000,size=20)
y1=np.random.randint(20000,30000,size=20)
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age and their salary")
plt.scatter(x,y,label="developers")
plt.scatter(x,y1,label="Data science")
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sci
import seaborn as sns

# %%
plt.figure(figsize=(6,6))
# plt.style.use('fivethirtyeight')
plt.title("The salarys and the ages pf the different domains")
x = np.linspace(22, 50, 20) 
y1 = 50000 + (x - 22) * 1500 + np.random.randint(-5000, 5000, size=20)
y2= 48000 + (x- 22) * 1400 + np.random.randint(-4000, 4000, size=20)
y3 = 60000 + (x - 22) * 2000 + np.random.randint(-6000, 6000, size=20)
# plt.grid()
plt.plot(x,y1,label="Python Developers",color="b",linewidth=2,linestyle="--",marker=".")
plt.plot(x,y2,label="Java Developers",color="red",linewidth=2,linestyle=":",marker="")
plt.plot(x,y3,label="Data Scientists")
plt.legend()
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# fig=plt.figure(figsize=(6,6),dpi=300)
fig,axs=plt.subplots(2,2,figsize=(12,10))
axs[0,0].set(xlabel="age",ylabel="salary",title="salary of the java ")
axs[0,1].set(xlabel="age",ylabel="salary",title="Salary of the python developers")
x = np.linspace(22, 50, 20) 
y1 = 50000 + (x - 22) * 1500 + np.random.randint(-5000, 5000, size=20)
y2= 48000 + (x- 22) * 1400 + np.random.randint(-4000, 4000, size=20)
y3 = 60000 + (x - 22) * 2000 + np.random.randint(-6000, 6000, size=20)
axs[0,0].plot(x,y1,label="Python Developers",color="r")
axs[0,1].bar(x,y2,label="Java Developers")
axs[1,0].plot(x,y2,label="Python Developers")
axs[1,1].bar(x,y1,label="Java Developers",color="red")
axs[0,0].legend()
plt.tight_layout()
# axs[0,0].grid(True)
# axs[0,1].grid(True)
# axs[1,0].grid(True)
# axs[1,1].grid(True)
plt.style.use('fivethirtyeight')
plt.show()
# axs[1].show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sci
import seaborn as sns
x = np.linspace(22, 50, 20) 
y1 = 50000 + (x - 22) * 1500 + np.random.randint(-5000, 5000, size=20)
y2= 48000 + (x- 22) * 1400 + np.random.randint(-4000, 4000, size=20)
y3 = 60000 + (x - 22) * 2000 + np.random.randint(-6000, 6000, size=20)
fig,axs=plt.subplots(2,2,figsize=(8,6))
axs[0,0].set(xlabel="Age",ylabel="Salary",title="Python developers salary")
axs[0,1].set(xlabel="Age",ylabel="Salary",title="java developers salary")
axs[1,0].set(xlabel="Age",ylabel="Salary",label="python developer",title="python developers salary")
axs[1,1].set(xlabel="Age",ylabel="Salary",label="Java developer",title="java developers salary")
axs[0,0].plot(x,y1,color="r",label="Python developer")
axs[0,1].plot(x,y2,color="g",marker="o",linewidth=2,linestyle=":",label="Java developer")
axs[1,0].bar(x,y1,color="blue",label="Python developer")
axs[1,1].bar(x,y2,color="purple",label="Java developer")
axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()
axs[0,0].grid(True)
axs[0,1].grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sci
df=pd.read_csv("titanics.csv")
# df["Age"]=df["Age"].fillna(df["Age"].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df["Age"].isna().sum()
# Out:
# 177

# %%
df["Age"]=df["Age"].fillna(int(df["Age"].mean()))

# %%
df["Age"].isna().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Age"]=df["Age"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(1), int32(1), int64(5), object(5)
# memory usage: 80.2+ KB

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male   29      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %%
plt.figure(figsize=(8,6))
plt.xlabel("Gender")
plt.ylabel("Survived")
plt.title("Survival rate")
survival_rate = df.groupby("Sex")["Survived"].sum()
# gender=df["Sex"].unique()
plt.bar(survival_rate.index,survival_rate.values,color=["b","pink"],width=0.5)
# for i, v in enumerate(survival_rate.values):
#     plt.text(i, v + 0.02, f"{v:.2%}", ha='center', fontsize=12)
plt.show()
print(survival_rate.index)
print(survival_rate.values)
# Out:
# Index(['female', 'male'], dtype='object', name='Sex')
# [233 109]

# %%
a=sns.heatmap(data=df.isnull())
for bar in a.containers:
    a.bar_label(bar, fmt="%.2f%%", label_type="edge", fontsize=12, color='black')
plt.show()

# %%
# pip install ydata-profiling

# %%
# from ydata_profiling import ProfileReport as pr
# dfs=pr(df,explorative=True)
# dfs
# dfs.to_file("report.html")

# %%
import ipywidgets as widgets
widgets.IntSlider()
# Out:
# IntSlider(value=0)

# %%
import numpy as np
import pandas as pd
import scipy as sci
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
df=pd.read_csv("titanics.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
mean_impute=SimpleImputer(strategy="mean")
df["Age"]=mean_impute.fit_transform(df[["Age"]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
plt.xlabel("Gender")
plt.ylabel("Survived rate")
z=df.groupby("Sex")["Survived"].mean()
plt.title("No of passengers and there age")
plt.bar(z.index,z.values,color=["violet","pink"],label=["Female","Male"])
plt.legend()
plt.show()

# %%
sns.histplot(x="Age",data=df,bins=10)
plt.show()

# %%
plt.title("Survival rate of titanic data set")
plt.pie(z.values,explode=[0,0.1],shadow=True,labels=z.index,wedgeprops={"edgecolor":"black"},autopct="%1.1f%%")
plt.show()

# %%
plt.boxplot(x=df["Age"],notch=True)
plt.show()

# %%
plt.figure(figsize=(12,8),dpi=300)
plt.xlabel("Persons")
plt.title("No of persons to their age group")
plt.ylabel("Age")
plt.scatter(x=df["Age"],y=np.random.randint(2,100,size=(891)),color="purple",label="Age")
plt.legend()
plt.show()

# %%
df["Age"].count()
# Out:
# 891

# %%
plt.barh(y=z.index,width=z.values,color=["red","blue"],label=z.index)
plt.legend()
plt.show()

# %%
fig,axs=plt.subplots(2,2,figsize=(12,8),dpi=600)
axs[0,0].set(xlabel=z.index[0],ylabel=z.index[1],title="Male and female survival rate")
axs[0,0].bar(x=z.index,height=z.values,color=["red","blue"],label=z.index)
axs[0,1].scatter(x=df["Age"],y=np.random.randint(2,100,size=(891)),color="purple",label="person")
axs[0,1].set(xlabel="Age",ylabel="No of people",title="Age group and there count")
axs[1,0].boxplot(x,notch=True)
axs[0,0].legend()
axs[0,1].legend()
plt.tight_layout()
plt.show()
