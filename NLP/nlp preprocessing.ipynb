# %%
# # import nltk
# from nltk.tokenize import word_tokenize
# from nltk.corpus import stopwords
# from nltk.stem import PorterStemmer
# import string

# nltk.download('punkt')
# nltk.download('stopwords')

# # Example text
# text = "The quick brown fox jumps over the lazy dog!"

# # 1️⃣ Lowercasing
# text = text.lower()

# # 2️⃣ Remove punctuation
# text=re.sub("[^a-z0-9\s]","",text)

# # 3️⃣ Tokenization
# tokens = word_tokenize(text)

# # 4️⃣ Stop word removal
# stop_words = set(stopwords.words('english'))
# filtered_tokens = [word for word in tokens if word not in stop_words]

# # 5️⃣ Stemming
# stemmer = PorterStemmer()
# stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]

# print(stemmed_tokens)

# %%
import nltk
import string
import re
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
# from nltk.lematization import Lemmatization

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data='''The quick brown fox jumps over the lazy dog. Artificial intelligence is transforming many industries today. She went to the market to buy some fresh vegetables and fruits. The weather forecast predicts heavy rain throughout the weekend. He decided to learn Python to advance his data science skills. Books are a uniquely portable magic, according to Stephen King. In 2025, electric vehicles will become even more affordable. They spent the afternoon exploring the ancient ruins near the village. Health experts recommend regular exercise and a balanced diet. A mysterious sound echoed through the empty hallways at night. The quick brown fox jumps over the lazy dog. Artificial intelligence is transforming many industries today. She went to the market to buy some fresh vegetables and fruits. The weather forecast predicts heavy rain throughout the weekend. He decided to learn Python to advance his data science skills. Books are a uniquely portable magic, according to Stephen King. In 2025, electric vehicles will become even more affordable. They spent the afternoon exploring the ancient ruins near the village. Health experts recommend regular exercise and a balanced diet. A mysterious sound echoed through the empty hallways at night. The quick brown fox jumps over the lazy dog. Artificial intelligence is transforming many industries today. She went to the market to buy some fresh vegetables and fruits. The weather forecast predicts heavy rain throughout the weekend. He decided to learn Python to advance his data science skills. Books are a uniquely portable magic, according to Stephen King. In 2025, electric vehicles will become even more affordable. They spent the afternoon exploring the ancient ruins near the village. Health experts recommend regular exercise and a balanced diet. A mysterious sound echoed through the empty hallways at night. The quick brown fox jumps over the lazy dog. Artificial intelligence is transforming many industries today. She went to the market to buy some fresh vegetables and fruits. The weather forecast predicts heavy rain throughout the weekend. He decided to learn Python to advance his data science skills. Books are a uniquely portable magic, according to Stephen King. In 2025, electric vehicles will become even more affordable. They spent the afternoon exploring the ancient ruins near the village. Health experts recommend regular exercise and a balanced diet. A mysterious sound echoed through the empty hallways at night. The quick brown fox jumps over the lazy dog. Artificial intelligence is transforming many industries today. She went to the market to buy some fresh vegetables and fruits. The weather forecast predicts heavy rain throughout the weekend. He decided to learn Python to advance his data science skills. Books are a uniquely portable magic, according to Stephen King. In 2025, electric vehicles will become even more affordable. They spent the afternoon exploring the ancient ruins near the village. Health experts recommend regular exercise and a balanced diet. A mysterious sound echoed through the empty hallways at night. The quick brown fox jumps over the lazy dog. Artificial intelligence is transforming many industries today. She went to the market to buy some fresh vegetables and fruits. The weather forecast predicts heavy rain throughout the weekend. He decided to learn Python to advance his data science skills. Books are a uniquely portable magic, according to Stephen King. In 2025, electric vehicles will become even more affordable. They spent the afternoon exploring the ancient ruins near the village. Health experts recommend regular exercise and a balanced diet. A mysterious sound echoed through the empty hallways at night. The quick brown fox jumps over the lazy dog. Artificial intelligence is transforming many industries today. She went to the market to buy some fresh vegetables and fruits. The weather forecast predicts heavy rain throughout the weekend. He decided to learn Python to advance his data science skills. Books are a uniquely portable magic, according to Stephen King.
In 2025,electric vehicles will become even more affordable. They spent the afternoon exploring the ancient ruins near the village. Health experts recommend regular exercise and a balanced diet. A mysterious sound echoed through the empty hallways at night.
'''

# %%
data=data.lower()

# %%
data=re.sub("[^a-z0-9\s]","",data)
data
# Out:
# 'the quick brown fox jumps over the lazy dog artificial intelligence is transforming many industries today she went to the market to buy some fresh vegetables and fruits the weather forecast predicts heavy rain throughout the weekend he decided to learn python to advance his data science skills books are a uniquely portable magic according to stephen king in 2025 electric vehicles will become even more affordable they spent the afternoon exploring the ancient ruins near the village health experts recommend regular exercise and a balanced diet a mysterious sound echoed through the empty hallways at night the quick brown fox jumps over the lazy dog artificial intelligence is transforming many industries today she went to the market to buy some fresh vegetables and fruits the weather forecast predicts heavy rain throughout the weekend he decided to learn python to advance his data science skills books are a uniquely portable magic according to stephen king in 2025 electric vehicles will become even more affordable they spent the afternoon exploring the ancient ruins near the village health experts recommend regular exercise and a balanced diet a mysterious sound echoed through the empty hallways at night the quick brown fox jumps over the lazy dog artificial intelligence is transforming many industries today she went to the market to buy some fresh vegetables and fruits the weather forecast predicts heavy rain throughout the weekend he decided to learn python to advance his data science skills books are a uniquely portable magic according to stephen king in 2025 electric vehicles will become even more affordable they spent the afternoon exploring the ancient ruins near the village health experts recommend regular exercise and a balanced diet a mysterious sound echoed through the empty hallways at night the quick brown fox jumps over the lazy dog artificial intelligence is transforming many industries today she went to the market to buy some fresh vegetables and fruits the weather forecast predicts heavy rain throughout the weekend he decided to learn python to advance his data science skills books are a uniquely portable magic according to stephen king in 2025 electric vehicles will become even more affordable they spent the afternoon exploring the ancient ruins near the village health experts recommend regular exercise and a balanced diet a mysterious sound echoed through the empty hallways at night the quick brown fox jumps over the lazy dog artificial intelligence is transforming many industries today she went to the market to buy some fresh vegetables and fruits the weather forecast predicts heavy rain throughout the weekend he decided to learn python to advance his data science skills books are a uniquely portable magic according to stephen king in 2025 electric vehicles will become even more affordable they spent the afternoon exploring the ancient ruins near the village health experts recommend regular exercise and a balanced diet a mysterious sound echoed through the empty hallways at night the quick brown fox jumps over the lazy dog artificial intelligence is transforming many industries today she went to the market to buy some fresh vegetables and fruits the weather forecast predicts heavy rain throughout the weekend he decided to learn python to advance his data science skills books are a uniquely portable magic according to stephen king in 2025 electric vehicles will become even more affordable they spent the afternoon exploring the ancient ruins near the village health experts recommend regular exercise and a balanced diet a mysterious sound echoed through the empty hallways at night the quick brown fox jumps over the lazy dog artificial intelligence is transforming many industries today she went to the market to buy some fresh vegetables and fruits the weather forecast predicts heavy rain throughout the weekend he decided to learn python to advance his data science skills books are a uniquely portable magic accordin ...

# %%
w_token=word_tokenize(data)
print(w_token)
# data.split(" ")
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', 'artificial', 'intelligence', 'is', 'transforming', 'many', 'industries', 'today', 'she', 'went', 'to', 'the', 'market', 'to', 'buy', 'some', 'fresh', 'vegetables', 'and', 'fruits', 'the', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'the', 'weekend', 'he', 'decided', 'to', 'learn', 'python', 'to', 'advance', 'his', 'data', 'science', 'skills', 'books', 'are', 'a', 'uniquely', 'portable', 'magic', 'according', 'to', 'stephen', 'king', 'in', '2025', 'electric', 'vehicles', 'will', 'become', 'even', 'more', 'affordable', 'they', 'spent', 'the', 'afternoon', 'exploring', 'the', 'ancient', 'ruins', 'near', 'the', 'village', 'health', 'experts', 'recommend', 'regular', 'exercise', 'and', 'a', 'balanced', 'diet', 'a', 'mysterious', 'sound', 'echoed', 'through', 'the', 'empty', 'hallways', 'at', 'night', 'the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', 'artificial', 'intelligence', 'is', 'transforming', 'many', 'industries', 'today', 'she', 'went', 'to', 'the', 'market', 'to', 'buy', 'some', 'fresh', 'vegetables', 'and', 'fruits', 'the', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'the', 'weekend', 'he', 'decided', 'to', 'learn', 'python', 'to', 'advance', 'his', 'data', 'science', 'skills', 'books', 'are', 'a', 'uniquely', 'portable', 'magic', 'according', 'to', 'stephen', 'king', 'in', '2025', 'electric', 'vehicles', 'will', 'become', 'even', 'more', 'affordable', 'they', 'spent', 'the', 'afternoon', 'exploring', 'the', 'ancient', 'ruins', 'near', 'the', 'village', 'health', 'experts', 'recommend', 'regular', 'exercise', 'and', 'a', 'balanced', 'diet', 'a', 'mysterious', 'sound', 'echoed', 'through', 'the', 'empty', 'hallways', 'at', 'night', 'the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', 'artificial', 'intelligence', 'is', 'transforming', 'many', 'industries', 'today', 'she', 'went', 'to', 'the', 'market', 'to', 'buy', 'some', 'fresh', 'vegetables', 'and', 'fruits', 'the', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'the', 'weekend', 'he', 'decided', 'to', 'learn', 'python', 'to', 'advance', 'his', 'data', 'science', 'skills', 'books', 'are', 'a', 'uniquely', 'portable', 'magic', 'according', 'to', 'stephen', 'king', 'in', '2025', 'electric', 'vehicles', 'will', 'become', 'even', 'more', 'affordable', 'they', 'spent', 'the', 'afternoon', 'exploring', 'the', 'ancient', 'ruins', 'near', 'the', 'village', 'health', 'experts', 'recommend', 'regular', 'exercise', 'and', 'a', 'balanced', 'diet', 'a', 'mysterious', 'sound', 'echoed', 'through', 'the', 'empty', 'hallways', 'at', 'night', 'the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', 'artificial', 'intelligence', 'is', 'transforming', 'many', 'industries', 'today', 'she', 'went', 'to', 'the', 'market', 'to', 'buy', 'some', 'fresh', 'vegetables', 'and', 'fruits', 'the', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'the', 'weekend', 'he', 'decided', 'to', 'learn', 'python', 'to', 'advance', 'his', 'data', 'science', 'skills', 'books', 'are', 'a', 'uniquely', 'portable', 'magic', 'according', 'to', 'stephen', 'king', 'in', '2025', 'electric', 'vehicles', 'will', 'become', 'even', 'more', 'affordable', 'they', 'spent', 'the', 'afternoon', 'exploring', 'the', 'ancient', 'ruins', 'near', 'the', 'village', 'health', 'experts', 'recommend', 'regular', 'exercise', 'and', 'a', 'balanced', 'diet', 'a', 'mysterious', 'sound', 'echoed', 'through', 'the', 'empty', 'hallways', 'at', 'night', 'the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', 'artificial', 'intelligence', 'is', 'transforming', 'many', 'industries', 'today', 'she', 'went', 'to', 'the', 'market', 'to', 'buy', 'some', 'fresh', 'vegetables', 'and', 'fruits', 'the', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'the', 'weekend', 'he', 'decided', 'to', 'learn', 'python', 'to', 'ad ...

# %%
stop_words=set(stopwords.words("english"))

# %%
clean=[]
data=[clean.append(i) for i in w_token if i not in stop_words]

# %%
print(clean)
# Out:
# ['quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', 'artificial', 'intelligence', 'transforming', 'many', 'industries', 'today', 'went', 'market', 'buy', 'fresh', 'vegetables', 'fruits', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'weekend', 'decided', 'learn', 'python', 'advance', 'data', 'science', 'skills', 'books', 'uniquely', 'portable', 'magic', 'according', 'stephen', 'king', '2025', 'electric', 'vehicles', 'become', 'even', 'affordable', 'spent', 'afternoon', 'exploring', 'ancient', 'ruins', 'near', 'village', 'health', 'experts', 'recommend', 'regular', 'exercise', 'balanced', 'diet', 'mysterious', 'sound', 'echoed', 'empty', 'hallways', 'night', 'quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', 'artificial', 'intelligence', 'transforming', 'many', 'industries', 'today', 'went', 'market', 'buy', 'fresh', 'vegetables', 'fruits', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'weekend', 'decided', 'learn', 'python', 'advance', 'data', 'science', 'skills', 'books', 'uniquely', 'portable', 'magic', 'according', 'stephen', 'king', '2025', 'electric', 'vehicles', 'become', 'even', 'affordable', 'spent', 'afternoon', 'exploring', 'ancient', 'ruins', 'near', 'village', 'health', 'experts', 'recommend', 'regular', 'exercise', 'balanced', 'diet', 'mysterious', 'sound', 'echoed', 'empty', 'hallways', 'night', 'quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', 'artificial', 'intelligence', 'transforming', 'many', 'industries', 'today', 'went', 'market', 'buy', 'fresh', 'vegetables', 'fruits', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'weekend', 'decided', 'learn', 'python', 'advance', 'data', 'science', 'skills', 'books', 'uniquely', 'portable', 'magic', 'according', 'stephen', 'king', '2025', 'electric', 'vehicles', 'become', 'even', 'affordable', 'spent', 'afternoon', 'exploring', 'ancient', 'ruins', 'near', 'village', 'health', 'experts', 'recommend', 'regular', 'exercise', 'balanced', 'diet', 'mysterious', 'sound', 'echoed', 'empty', 'hallways', 'night', 'quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', 'artificial', 'intelligence', 'transforming', 'many', 'industries', 'today', 'went', 'market', 'buy', 'fresh', 'vegetables', 'fruits', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'weekend', 'decided', 'learn', 'python', 'advance', 'data', 'science', 'skills', 'books', 'uniquely', 'portable', 'magic', 'according', 'stephen', 'king', '2025', 'electric', 'vehicles', 'become', 'even', 'affordable', 'spent', 'afternoon', 'exploring', 'ancient', 'ruins', 'near', 'village', 'health', 'experts', 'recommend', 'regular', 'exercise', 'balanced', 'diet', 'mysterious', 'sound', 'echoed', 'empty', 'hallways', 'night', 'quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', 'artificial', 'intelligence', 'transforming', 'many', 'industries', 'today', 'went', 'market', 'buy', 'fresh', 'vegetables', 'fruits', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'weekend', 'decided', 'learn', 'python', 'advance', 'data', 'science', 'skills', 'books', 'uniquely', 'portable', 'magic', 'according', 'stephen', 'king', '2025', 'electric', 'vehicles', 'become', 'even', 'affordable', 'spent', 'afternoon', 'exploring', 'ancient', 'ruins', 'near', 'village', 'health', 'experts', 'recommend', 'regular', 'exercise', 'balanced', 'diet', 'mysterious', 'sound', 'echoed', 'empty', 'hallways', 'night', 'quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', 'artificial', 'intelligence', 'transforming', 'many', 'industries', 'today', 'went', 'market', 'buy', 'fresh', 'vegetables', 'fruits', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'weekend', 'decided', 'learn', 'python', 'advance', 'data', 'science', 'skills', 'books', 'uniquely', 'portable', 'magic', 'according', 'stephen', 'king', '2025', 'electric', 'vehicles', 'become', 'even', 'affordable', 'spent', 'afternoon', 'exploring', 'ancient', 'ruins', 'near', 'village', 'health', 'experts', 'recommend', 'regula ...

# %%
stem=PorterStemmer()

# %%
filtered=[stem.stem(i) for i in clean]

# %%
print(filtered)
# Out:
# ['quick', 'brown', 'fox', 'jump', 'lazi', 'dog', 'artifici', 'intellig', 'transform', 'mani', 'industri', 'today', 'went', 'market', 'buy', 'fresh', 'veget', 'fruit', 'weather', 'forecast', 'predict', 'heavi', 'rain', 'throughout', 'weekend', 'decid', 'learn', 'python', 'advanc', 'data', 'scienc', 'skill', 'book', 'uniqu', 'portabl', 'magic', 'accord', 'stephen', 'king', '2025', 'electr', 'vehicl', 'becom', 'even', 'afford', 'spent', 'afternoon', 'explor', 'ancient', 'ruin', 'near', 'villag', 'health', 'expert', 'recommend', 'regular', 'exercis', 'balanc', 'diet', 'mysteri', 'sound', 'echo', 'empti', 'hallway', 'night', 'quick', 'brown', 'fox', 'jump', 'lazi', 'dog', 'artifici', 'intellig', 'transform', 'mani', 'industri', 'today', 'went', 'market', 'buy', 'fresh', 'veget', 'fruit', 'weather', 'forecast', 'predict', 'heavi', 'rain', 'throughout', 'weekend', 'decid', 'learn', 'python', 'advanc', 'data', 'scienc', 'skill', 'book', 'uniqu', 'portabl', 'magic', 'accord', 'stephen', 'king', '2025', 'electr', 'vehicl', 'becom', 'even', 'afford', 'spent', 'afternoon', 'explor', 'ancient', 'ruin', 'near', 'villag', 'health', 'expert', 'recommend', 'regular', 'exercis', 'balanc', 'diet', 'mysteri', 'sound', 'echo', 'empti', 'hallway', 'night', 'quick', 'brown', 'fox', 'jump', 'lazi', 'dog', 'artifici', 'intellig', 'transform', 'mani', 'industri', 'today', 'went', 'market', 'buy', 'fresh', 'veget', 'fruit', 'weather', 'forecast', 'predict', 'heavi', 'rain', 'throughout', 'weekend', 'decid', 'learn', 'python', 'advanc', 'data', 'scienc', 'skill', 'book', 'uniqu', 'portabl', 'magic', 'accord', 'stephen', 'king', '2025', 'electr', 'vehicl', 'becom', 'even', 'afford', 'spent', 'afternoon', 'explor', 'ancient', 'ruin', 'near', 'villag', 'health', 'expert', 'recommend', 'regular', 'exercis', 'balanc', 'diet', 'mysteri', 'sound', 'echo', 'empti', 'hallway', 'night', 'quick', 'brown', 'fox', 'jump', 'lazi', 'dog', 'artifici', 'intellig', 'transform', 'mani', 'industri', 'today', 'went', 'market', 'buy', 'fresh', 'veget', 'fruit', 'weather', 'forecast', 'predict', 'heavi', 'rain', 'throughout', 'weekend', 'decid', 'learn', 'python', 'advanc', 'data', 'scienc', 'skill', 'book', 'uniqu', 'portabl', 'magic', 'accord', 'stephen', 'king', '2025', 'electr', 'vehicl', 'becom', 'even', 'afford', 'spent', 'afternoon', 'explor', 'ancient', 'ruin', 'near', 'villag', 'health', 'expert', 'recommend', 'regular', 'exercis', 'balanc', 'diet', 'mysteri', 'sound', 'echo', 'empti', 'hallway', 'night', 'quick', 'brown', 'fox', 'jump', 'lazi', 'dog', 'artifici', 'intellig', 'transform', 'mani', 'industri', 'today', 'went', 'market', 'buy', 'fresh', 'veget', 'fruit', 'weather', 'forecast', 'predict', 'heavi', 'rain', 'throughout', 'weekend', 'decid', 'learn', 'python', 'advanc', 'data', 'scienc', 'skill', 'book', 'uniqu', 'portabl', 'magic', 'accord', 'stephen', 'king', '2025', 'electr', 'vehicl', 'becom', 'even', 'afford', 'spent', 'afternoon', 'explor', 'ancient', 'ruin', 'near', 'villag', 'health', 'expert', 'recommend', 'regular', 'exercis', 'balanc', 'diet', 'mysteri', 'sound', 'echo', 'empti', 'hallway', 'night', 'quick', 'brown', 'fox', 'jump', 'lazi', 'dog', 'artifici', 'intellig', 'transform', 'mani', 'industri', 'today', 'went', 'market', 'buy', 'fresh', 'veget', 'fruit', 'weather', 'forecast', 'predict', 'heavi', 'rain', 'throughout', 'weekend', 'decid', 'learn', 'python', 'advanc', 'data', 'scienc', 'skill', 'book', 'uniqu', 'portabl', 'magic', 'accord', 'stephen', 'king', '2025', 'electr', 'vehicl', 'becom', 'even', 'afford', 'spent', 'afternoon', 'explor', 'ancient', 'ruin', 'near', 'villag', 'health', 'expert', 'recommend', 'regular', 'exercis', 'balanc', 'diet', 'mysteri', 'sound', 'echo', 'empti', 'hallway', 'night', 'quick', 'brown', 'fox', 'jump', 'lazi', 'dog', 'artifici', 'intellig', 'transform', 'mani', 'industri', 'today', 'went', 'market', 'buy', 'fresh', 'veget', 'fruit', 'weather', 'forecast', 'predict', 'heavi', 'rain', 'throughout', 'weeke ...

# %%
from collections import Counter
counter=Counter(filtered)

# %%
from nltk.stem import WordNetLemmatizer
lemma=WordNetLemmatizer()
lemmatized=[lemma.lemmatize(i) for i in clean]

# %%
print(lemmatized)
# Out:
# ['quick', 'brown', 'fox', 'jump', 'lazy', 'dog', 'artificial', 'intelligence', 'transforming', 'many', 'industry', 'today', 'went', 'market', 'buy', 'fresh', 'vegetable', 'fruit', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'weekend', 'decided', 'learn', 'python', 'advance', 'data', 'science', 'skill', 'book', 'uniquely', 'portable', 'magic', 'according', 'stephen', 'king', '2025', 'electric', 'vehicle', 'become', 'even', 'affordable', 'spent', 'afternoon', 'exploring', 'ancient', 'ruin', 'near', 'village', 'health', 'expert', 'recommend', 'regular', 'exercise', 'balanced', 'diet', 'mysterious', 'sound', 'echoed', 'empty', 'hallway', 'night', 'quick', 'brown', 'fox', 'jump', 'lazy', 'dog', 'artificial', 'intelligence', 'transforming', 'many', 'industry', 'today', 'went', 'market', 'buy', 'fresh', 'vegetable', 'fruit', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'weekend', 'decided', 'learn', 'python', 'advance', 'data', 'science', 'skill', 'book', 'uniquely', 'portable', 'magic', 'according', 'stephen', 'king', '2025', 'electric', 'vehicle', 'become', 'even', 'affordable', 'spent', 'afternoon', 'exploring', 'ancient', 'ruin', 'near', 'village', 'health', 'expert', 'recommend', 'regular', 'exercise', 'balanced', 'diet', 'mysterious', 'sound', 'echoed', 'empty', 'hallway', 'night', 'quick', 'brown', 'fox', 'jump', 'lazy', 'dog', 'artificial', 'intelligence', 'transforming', 'many', 'industry', 'today', 'went', 'market', 'buy', 'fresh', 'vegetable', 'fruit', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'weekend', 'decided', 'learn', 'python', 'advance', 'data', 'science', 'skill', 'book', 'uniquely', 'portable', 'magic', 'according', 'stephen', 'king', '2025', 'electric', 'vehicle', 'become', 'even', 'affordable', 'spent', 'afternoon', 'exploring', 'ancient', 'ruin', 'near', 'village', 'health', 'expert', 'recommend', 'regular', 'exercise', 'balanced', 'diet', 'mysterious', 'sound', 'echoed', 'empty', 'hallway', 'night', 'quick', 'brown', 'fox', 'jump', 'lazy', 'dog', 'artificial', 'intelligence', 'transforming', 'many', 'industry', 'today', 'went', 'market', 'buy', 'fresh', 'vegetable', 'fruit', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'weekend', 'decided', 'learn', 'python', 'advance', 'data', 'science', 'skill', 'book', 'uniquely', 'portable', 'magic', 'according', 'stephen', 'king', '2025', 'electric', 'vehicle', 'become', 'even', 'affordable', 'spent', 'afternoon', 'exploring', 'ancient', 'ruin', 'near', 'village', 'health', 'expert', 'recommend', 'regular', 'exercise', 'balanced', 'diet', 'mysterious', 'sound', 'echoed', 'empty', 'hallway', 'night', 'quick', 'brown', 'fox', 'jump', 'lazy', 'dog', 'artificial', 'intelligence', 'transforming', 'many', 'industry', 'today', 'went', 'market', 'buy', 'fresh', 'vegetable', 'fruit', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'weekend', 'decided', 'learn', 'python', 'advance', 'data', 'science', 'skill', 'book', 'uniquely', 'portable', 'magic', 'according', 'stephen', 'king', '2025', 'electric', 'vehicle', 'become', 'even', 'affordable', 'spent', 'afternoon', 'exploring', 'ancient', 'ruin', 'near', 'village', 'health', 'expert', 'recommend', 'regular', 'exercise', 'balanced', 'diet', 'mysterious', 'sound', 'echoed', 'empty', 'hallway', 'night', 'quick', 'brown', 'fox', 'jump', 'lazy', 'dog', 'artificial', 'intelligence', 'transforming', 'many', 'industry', 'today', 'went', 'market', 'buy', 'fresh', 'vegetable', 'fruit', 'weather', 'forecast', 'predicts', 'heavy', 'rain', 'throughout', 'weekend', 'decided', 'learn', 'python', 'advance', 'data', 'science', 'skill', 'book', 'uniquely', 'portable', 'magic', 'according', 'stephen', 'king', '2025', 'electric', 'vehicle', 'become', 'even', 'affordable', 'spent', 'afternoon', 'exploring', 'ancient', 'ruin', 'near', 'village', 'health', 'expert', 'recommend', 'regular', 'exercise', 'balanced', 'diet', 'mysterious', 'sound', 'echoe ...

# %%
grammer=nltk.pos_tag(lemmatized)

# %%
print(grammer)
# Out:
# [('quick', 'JJ'), ('brown', 'NN'), ('fox', 'JJ'), ('jump', 'NN'), ('lazy', 'NN'), ('dog', 'NN'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('transforming', 'VBG'), ('many', 'JJ'), ('industry', 'NN'), ('today', 'NN'), ('went', 'VBD'), ('market', 'NN'), ('buy', 'NN'), ('fresh', 'JJ'), ('vegetable', 'JJ'), ('fruit', 'NN'), ('weather', 'NN'), ('forecast', 'NN'), ('predicts', 'VBZ'), ('heavy', 'JJ'), ('rain', 'NN'), ('throughout', 'IN'), ('weekend', 'NN'), ('decided', 'VBD'), ('learn', 'JJ'), ('python', 'NN'), ('advance', 'NN'), ('data', 'NNS'), ('science', 'NN'), ('skill', 'NN'), ('book', 'NN'), ('uniquely', 'RB'), ('portable', 'JJ'), ('magic', 'NNS'), ('according', 'VBG'), ('stephen', 'NN'), ('king', 'NN'), ('2025', 'CD'), ('electric', 'JJ'), ('vehicle', 'NN'), ('become', 'VB'), ('even', 'RB'), ('affordable', 'JJ'), ('spent', 'JJ'), ('afternoon', 'NN'), ('exploring', 'VBG'), ('ancient', 'JJ'), ('ruin', 'NN'), ('near', 'IN'), ('village', 'NN'), ('health', 'NN'), ('expert', 'JJ'), ('recommend', 'VBP'), ('regular', 'JJ'), ('exercise', 'NN'), ('balanced', 'VBD'), ('diet', 'JJ'), ('mysterious', 'JJ'), ('sound', 'NN'), ('echoed', 'VBD'), ('empty', 'JJ'), ('hallway', 'RB'), ('night', 'NN'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'JJ'), ('jump', 'NN'), ('lazy', 'NN'), ('dog', 'NN'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('transforming', 'VBG'), ('many', 'JJ'), ('industry', 'NN'), ('today', 'NN'), ('went', 'VBD'), ('market', 'NN'), ('buy', 'NN'), ('fresh', 'JJ'), ('vegetable', 'JJ'), ('fruit', 'NN'), ('weather', 'NN'), ('forecast', 'NN'), ('predicts', 'VBZ'), ('heavy', 'JJ'), ('rain', 'NN'), ('throughout', 'IN'), ('weekend', 'NN'), ('decided', 'VBD'), ('learn', 'JJ'), ('python', 'NN'), ('advance', 'NN'), ('data', 'NNS'), ('science', 'NN'), ('skill', 'NN'), ('book', 'NN'), ('uniquely', 'RB'), ('portable', 'JJ'), ('magic', 'NNS'), ('according', 'VBG'), ('stephen', 'NN'), ('king', 'NN'), ('2025', 'CD'), ('electric', 'JJ'), ('vehicle', 'NN'), ('become', 'VB'), ('even', 'RB'), ('affordable', 'JJ'), ('spent', 'JJ'), ('afternoon', 'NN'), ('exploring', 'VBG'), ('ancient', 'JJ'), ('ruin', 'NN'), ('near', 'IN'), ('village', 'NN'), ('health', 'NN'), ('expert', 'JJ'), ('recommend', 'VBP'), ('regular', 'JJ'), ('exercise', 'NN'), ('balanced', 'VBD'), ('diet', 'JJ'), ('mysterious', 'JJ'), ('sound', 'NN'), ('echoed', 'VBD'), ('empty', 'JJ'), ('hallway', 'RB'), ('night', 'NN'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'JJ'), ('jump', 'NN'), ('lazy', 'NN'), ('dog', 'NN'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('transforming', 'VBG'), ('many', 'JJ'), ('industry', 'NN'), ('today', 'NN'), ('went', 'VBD'), ('market', 'NN'), ('buy', 'NN'), ('fresh', 'JJ'), ('vegetable', 'JJ'), ('fruit', 'NN'), ('weather', 'NN'), ('forecast', 'NN'), ('predicts', 'VBZ'), ('heavy', 'JJ'), ('rain', 'NN'), ('throughout', 'IN'), ('weekend', 'NN'), ('decided', 'VBD'), ('learn', 'JJ'), ('python', 'NN'), ('advance', 'NN'), ('data', 'NNS'), ('science', 'NN'), ('skill', 'NN'), ('book', 'NN'), ('uniquely', 'RB'), ('portable', 'JJ'), ('magic', 'NNS'), ('according', 'VBG'), ('stephen', 'NN'), ('king', 'NN'), ('2025', 'CD'), ('electric', 'JJ'), ('vehicle', 'NN'), ('become', 'VB'), ('even', 'RB'), ('affordable', 'JJ'), ('spent', 'JJ'), ('afternoon', 'NN'), ('exploring', 'VBG'), ('ancient', 'JJ'), ('ruin', 'NN'), ('near', 'IN'), ('village', 'NN'), ('health', 'NN'), ('expert', 'JJ'), ('recommend', 'VBP'), ('regular', 'JJ'), ('exercise', 'NN'), ('balanced', 'VBD'), ('diet', 'JJ'), ('mysterious', 'JJ'), ('sound', 'NN'), ('echoed', 'VBD'), ('empty', 'JJ'), ('hallway', 'RB'), ('night', 'NN'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'JJ'), ('jump', 'NN'), ('lazy', 'NN'), ('dog', 'NN'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('transforming', 'VBG'), ('many', 'JJ'), ('industry', 'NN'), ('today', 'NN'), ('went', 'VBD'), ('market', 'NN'), ('buy', 'NN'), ('fresh', 'JJ'), ('vegetable', 'JJ'), ('fruit', 'NN'), ('weather', 'NN'), ('forecast', 'NN'), ('predicts', 'VBZ'), ('hea ...

# %%
import nltk 
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer,WordNetLemmatizer

# %%
corpus='''Artificial Intelligence, often abbreviated as AI, has become one of the most significant technological developments of the 21st century. At its core, AI refers to the ability of machines to mimic or replicate human cognitive functions such as learning, reasoning, problem-solving, perception, and language understanding. This field has its roots in computer science, mathematics, and cognitive science, blending these disciplines to create systems that can process information and make decisions independently.

The journey of AI began decades ago, with early pioneers like Alan Turing and John McCarthy laying the theoretical groundwork. Turing’s famous question—“Can machines think?”—sparked debates that continue to this day. McCarthy, often called the father of AI, coined the term “Artificial Intelligence” in 1956 during the Dartmouth Conference, where he and other researchers imagined a future in which machines could simulate human intelligence.

Since those early days, AI has evolved dramatically. The field has seen periods of rapid progress and significant setbacks, known as “AI winters,” when interest and funding waned due to unmet expectations. However, the advent of powerful computers, access to massive datasets, and breakthroughs in machine learning have propelled AI into the mainstream.

Machine learning, a subset of AI, enables systems to learn from data and improve their performance over time without explicit programming. It involves training algorithms on large datasets so they can recognize patterns and make predictions. A particularly influential technique is deep learning, which uses neural networks modeled after the human brain’s interconnected neurons. These networks have multiple layers that process data at increasing levels of abstraction, allowing them to handle complex tasks like image recognition, speech synthesis, and natural language processing.

One of the most visible applications of AI is in natural language processing (NLP), which focuses on enabling computers to understand, interpret, and generate human language. From voice assistants like Siri and Alexa to advanced translation tools and chatbots, NLP has become an integral part of our daily lives. Large language models, such as those developed by OpenAI and other organizations, can produce human-like text, answer questions, and even compose poetry or code.

AI has also made remarkable strides in computer vision. Systems can now identify objects in images, recognize faces, and even detect emotions. These technologies power everything from social media photo tagging to autonomous vehicles. Self-driving cars, for example, use AI-powered perception systems to detect pedestrians, traffic signs, and obstacles, making real-time decisions to navigate safely.

Another important area of AI research is reinforcement learning, where systems learn by interacting with their environment and receiving feedback in the form of rewards or penalties. This approach has been used to train AI to play complex games like chess, Go, and video games such as StarCraft. Reinforcement learning has also been applied in robotics, where robots learn to manipulate objects and navigate unfamiliar spaces.

Despite these achievements, AI is not without its challenges. Bias and fairness have become major concerns, as AI systems can inherit and amplify biases present in training data. For instance, facial recognition systems have shown disparities in accuracy across different demographic groups, raising ethical and social questions. Researchers and policymakers are actively working to develop guidelines and standards that ensure AI is transparent, fair, and accountable.

Ethical considerations extend beyond bias. The increasing use of AI in decision-making processes, from hiring to criminal justice, has sparked debates about the potential for unintended consequences. Some experts advocate for explainable AI (XAI), which seeks to make AI’s decision-making process more understandable to humans. Transparency and interpretability are crucial for building trust in AI systems.

The potential impact of AI on employment is another topic of intense discussion. While AI can automate repetitive and dangerous tasks, leading to increased productivity and safety, it also poses challenges for workers whose jobs may be displaced. Economists and policymakers are exploring ways to adapt to these shifts, such as retraining programs and social safety nets to support workers in transitioning to new roles.

Beyond individual applications, AI has the potential to address some of the world’s most pressing challenges. In healthcare, AI systems can analyze vast amounts of medical data to identify disease patterns and assist in diagnosis. AI-powered tools can help researchers discover new drugs, accelerate clinical trials, and personalize treatments based on genetic information.

In environmental sustainability, AI is being used to optimize energy use, monitor ecosystems, and predict climate-related events. Smart grids powered by AI can balance electricity demand and supply, while AI-driven climate models help researchers understand and respond to the impacts of climate change.

The future of AI holds both promise and uncertainty. As technology continues to advance, questions arise about how to balance innovation with responsible use. Leading AI researchers and organizations have called for collaboration among governments, academia, and industry to establish best practices and ethical frameworks for AI development.

There is also a growing movement toward open-source AI, where models and tools are shared openly to encourage collaboration and democratize access. This approach fosters innovation and allows diverse voices to participate in shaping the future of AI. However, concerns about misuse and security remain, as AI can also be used to create misinformation, deepfakes, and other harmful applications.

As we stand at the intersection of possibility and responsibility, the story of AI is still being written. It is a field that invites curiosity, creativity, and caution in equal measure. Researchers continue to push the boundaries of what machines can do, from language models that rival human writers to robots that learn from their surroundings.

Ultimately, AI reflects our collective ambitions and fears, our hopes for a better future and our anxieties about losing control. In every algorithm and dataset, we see glimpses of ourselves—our intelligence, our biases, our creativity, and our contradictions. The conversation around AI is a conversation about what it means to be human in an age of intelligent machines.

In this rapidly evolving landscape, one thing is certain: AI is not a distant dream or a futuristic fantasy. It is a present reality, woven into the fabric of our lives, shaping how we work, communicate, and solve problems. As we navigate this new world, the choices we make today will determine the role AI plays in our shared future—whether as a tool for progress, a mirror of our values, or a challenge to our understanding of what it means to think and feel.'''

# %%
corpus=corpus.lower()

# %%
import re
corpus=re.sub("[^a-z0-9\s]","",corpus)

# %%
corpus=re.sub("\n","",corpus)
corpus
# Out:
# 'artificial intelligence often abbreviated as ai has become one of the most significant technological developments of the 21st century at its core ai refers to the ability of machines to mimic or replicate human cognitive functions such as learning reasoning problemsolving perception and language understanding this field has its roots in computer science mathematics and cognitive science blending these disciplines to create systems that can process information and make decisions independentlythe journey of ai began decades ago with early pioneers like alan turing and john mccarthy laying the theoretical groundwork turings famous questioncan machines thinksparked debates that continue to this day mccarthy often called the father of ai coined the term artificial intelligence in 1956 during the dartmouth conference where he and other researchers imagined a future in which machines could simulate human intelligencesince those early days ai has evolved dramatically the field has seen periods of rapid progress and significant setbacks known as ai winters when interest and funding waned due to unmet expectations however the advent of powerful computers access to massive datasets and breakthroughs in machine learning have propelled ai into the mainstreammachine learning a subset of ai enables systems to learn from data and improve their performance over time without explicit programming it involves training algorithms on large datasets so they can recognize patterns and make predictions a particularly influential technique is deep learning which uses neural networks modeled after the human brains interconnected neurons these networks have multiple layers that process data at increasing levels of abstraction allowing them to handle complex tasks like image recognition speech synthesis and natural language processingone of the most visible applications of ai is in natural language processing nlp which focuses on enabling computers to understand interpret and generate human language from voice assistants like siri and alexa to advanced translation tools and chatbots nlp has become an integral part of our daily lives large language models such as those developed by openai and other organizations can produce humanlike text answer questions and even compose poetry or codeai has also made remarkable strides in computer vision systems can now identify objects in images recognize faces and even detect emotions these technologies power everything from social media photo tagging to autonomous vehicles selfdriving cars for example use aipowered perception systems to detect pedestrians traffic signs and obstacles making realtime decisions to navigate safelyanother important area of ai research is reinforcement learning where systems learn by interacting with their environment and receiving feedback in the form of rewards or penalties this approach has been used to train ai to play complex games like chess go and video games such as starcraft reinforcement learning has also been applied in robotics where robots learn to manipulate objects and navigate unfamiliar spacesdespite these achievements ai is not without its challenges bias and fairness have become major concerns as ai systems can inherit and amplify biases present in training data for instance facial recognition systems have shown disparities in accuracy across different demographic groups raising ethical and social questions researchers and policymakers are actively working to develop guidelines and standards that ensure ai is transparent fair and accountableethical considerations extend beyond bias the increasing use of ai in decisionmaking processes from hiring to criminal justice has sparked debates about the potential for unintended consequences some experts advocate for explainable ai xai which seeks to make ais decisionmaking process more understandable to humans transparency and interpretability are crucial for building trust in ai systemsthe potential impact of ai on employment is ...

# %%
token=word_tokenize(corpus)

# %%
print(token)
# Out:
# ['artificial', 'intelligence', 'often', 'abbreviated', 'as', 'ai', 'has', 'become', 'one', 'of', 'the', 'most', 'significant', 'technological', 'developments', 'of', 'the', '21st', 'century', 'at', 'its', 'core', 'ai', 'refers', 'to', 'the', 'ability', 'of', 'machines', 'to', 'mimic', 'or', 'replicate', 'human', 'cognitive', 'functions', 'such', 'as', 'learning', 'reasoning', 'problemsolving', 'perception', 'and', 'language', 'understanding', 'this', 'field', 'has', 'its', 'roots', 'in', 'computer', 'science', 'mathematics', 'and', 'cognitive', 'science', 'blending', 'these', 'disciplines', 'to', 'create', 'systems', 'that', 'can', 'process', 'information', 'and', 'make', 'decisions', 'independentlythe', 'journey', 'of', 'ai', 'began', 'decades', 'ago', 'with', 'early', 'pioneers', 'like', 'alan', 'turing', 'and', 'john', 'mccarthy', 'laying', 'the', 'theoretical', 'groundwork', 'turings', 'famous', 'questioncan', 'machines', 'thinksparked', 'debates', 'that', 'continue', 'to', 'this', 'day', 'mccarthy', 'often', 'called', 'the', 'father', 'of', 'ai', 'coined', 'the', 'term', 'artificial', 'intelligence', 'in', '1956', 'during', 'the', 'dartmouth', 'conference', 'where', 'he', 'and', 'other', 'researchers', 'imagined', 'a', 'future', 'in', 'which', 'machines', 'could', 'simulate', 'human', 'intelligencesince', 'those', 'early', 'days', 'ai', 'has', 'evolved', 'dramatically', 'the', 'field', 'has', 'seen', 'periods', 'of', 'rapid', 'progress', 'and', 'significant', 'setbacks', 'known', 'as', 'ai', 'winters', 'when', 'interest', 'and', 'funding', 'waned', 'due', 'to', 'unmet', 'expectations', 'however', 'the', 'advent', 'of', 'powerful', 'computers', 'access', 'to', 'massive', 'datasets', 'and', 'breakthroughs', 'in', 'machine', 'learning', 'have', 'propelled', 'ai', 'into', 'the', 'mainstreammachine', 'learning', 'a', 'subset', 'of', 'ai', 'enables', 'systems', 'to', 'learn', 'from', 'data', 'and', 'improve', 'their', 'performance', 'over', 'time', 'without', 'explicit', 'programming', 'it', 'involves', 'training', 'algorithms', 'on', 'large', 'datasets', 'so', 'they', 'can', 'recognize', 'patterns', 'and', 'make', 'predictions', 'a', 'particularly', 'influential', 'technique', 'is', 'deep', 'learning', 'which', 'uses', 'neural', 'networks', 'modeled', 'after', 'the', 'human', 'brains', 'interconnected', 'neurons', 'these', 'networks', 'have', 'multiple', 'layers', 'that', 'process', 'data', 'at', 'increasing', 'levels', 'of', 'abstraction', 'allowing', 'them', 'to', 'handle', 'complex', 'tasks', 'like', 'image', 'recognition', 'speech', 'synthesis', 'and', 'natural', 'language', 'processingone', 'of', 'the', 'most', 'visible', 'applications', 'of', 'ai', 'is', 'in', 'natural', 'language', 'processing', 'nlp', 'which', 'focuses', 'on', 'enabling', 'computers', 'to', 'understand', 'interpret', 'and', 'generate', 'human', 'language', 'from', 'voice', 'assistants', 'like', 'siri', 'and', 'alexa', 'to', 'advanced', 'translation', 'tools', 'and', 'chatbots', 'nlp', 'has', 'become', 'an', 'integral', 'part', 'of', 'our', 'daily', 'lives', 'large', 'language', 'models', 'such', 'as', 'those', 'developed', 'by', 'openai', 'and', 'other', 'organizations', 'can', 'produce', 'humanlike', 'text', 'answer', 'questions', 'and', 'even', 'compose', 'poetry', 'or', 'codeai', 'has', 'also', 'made', 'remarkable', 'strides', 'in', 'computer', 'vision', 'systems', 'can', 'now', 'identify', 'objects', 'in', 'images', 'recognize', 'faces', 'and', 'even', 'detect', 'emotions', 'these', 'technologies', 'power', 'everything', 'from', 'social', 'media', 'photo', 'tagging', 'to', 'autonomous', 'vehicles', 'selfdriving', 'cars', 'for', 'example', 'use', 'aipowered', 'perception', 'systems', 'to', 'detect', 'pedestrians', 'traffic', 'signs', 'and', 'obstacles', 'making', 'realtime', 'decisions', 'to', 'navigate', 'safelyanother', 'important', 'area', 'of', 'ai', 'research', 'is', 'reinforcement', 'learning', 'where', 'systems', 'learn', 'by', 'interacting', ...

# %%
stop_words=set(stop_words)
print(stop_words)
# Out:
# {"he'd", 'same', 'only', "doesn't", 'very', "weren't", 'to', 'hers', 'more', 'were', 'their', 'her', 'his', 'nor', "you'd", 'ain', "shouldn't", 'above', 'these', 'your', "wasn't", 'on', "mightn't", 'do', "should've", 'been', 'doesn', 'himself', 'below', 'and', 'have', 'don', 'our', 'or', 'will', 'other', "shan't", 'as', "it'll", 'ma', 'too', 'o', 'further', 're', 'wouldn', 'for', 'between', 'am', 'each', 'how', "i'm", 'some', "she's", 'out', 'being', 'an', 'few', 'whom', "that'll", 'before', 'shouldn', "it's", "you've", "he'll", 'hasn', 'here', 'if', 'this', "they've", 'needn', 'by', 'mightn', 'own', 'themselves', 'didn', 'who', 'aren', 'couldn', 'under', 'm', 'herself', 'is', "don't", 's', 'did', 'until', 'a', 'but', 'it', 'its', 'any', "isn't", "we'd", 'over', 'i', 'off', "she'll", 'yourselves', 'hadn', 'yours', 'no', 'll', 'not', 'about', "it'd", 'weren', "aren't", 'wasn', 'while', 'the', 'against', 'he', 'mustn', "we'll", 'into', 'at', 'ourselves', 've', "you'll", 'ours', 'which', 'because', 'having', 'from', 'down', 'has', 'him', 'those', 'so', 'you', 'just', "won't", 'once', "i've", 'all', 'y', 'she', 'that', 'when', 'was', 'does', 'be', 'should', 'won', 'of', "needn't", 'both', 'me', 'are', 'why', "they'd", "hadn't", 'my', 'can', 'now', 'such', 'them', 'most', "mustn't", 'myself', 'up', "couldn't", 'in', 'itself', 'again', 'had', 'doing', "i'd", 't', 'shan', 'what', "we've", 'haven', "you're", 'yourself', "they're", 'we', 'through', "hasn't", 'there', "he's", "haven't", "wouldn't", "didn't", 'they', 'where', 'than', "we're", 'isn', 'd', 'theirs', "they'll", 'during', 'after', "i'll", 'then', "she'd", 'with'}

# %%
removed=[i for i in token if i not in stop_words]
print(removed)
# Out:
# ['artificial', 'intelligence', 'often', 'abbreviated', 'ai', 'become', 'one', 'significant', 'technological', 'developments', '21st', 'century', 'core', 'ai', 'refers', 'ability', 'machines', 'mimic', 'replicate', 'human', 'cognitive', 'functions', 'learning', 'reasoning', 'problemsolving', 'perception', 'language', 'understanding', 'field', 'roots', 'computer', 'science', 'mathematics', 'cognitive', 'science', 'blending', 'disciplines', 'create', 'systems', 'process', 'information', 'make', 'decisions', 'independentlythe', 'journey', 'ai', 'began', 'decades', 'ago', 'early', 'pioneers', 'like', 'alan', 'turing', 'john', 'mccarthy', 'laying', 'theoretical', 'groundwork', 'turings', 'famous', 'questioncan', 'machines', 'thinksparked', 'debates', 'continue', 'day', 'mccarthy', 'often', 'called', 'father', 'ai', 'coined', 'term', 'artificial', 'intelligence', '1956', 'dartmouth', 'conference', 'researchers', 'imagined', 'future', 'machines', 'could', 'simulate', 'human', 'intelligencesince', 'early', 'days', 'ai', 'evolved', 'dramatically', 'field', 'seen', 'periods', 'rapid', 'progress', 'significant', 'setbacks', 'known', 'ai', 'winters', 'interest', 'funding', 'waned', 'due', 'unmet', 'expectations', 'however', 'advent', 'powerful', 'computers', 'access', 'massive', 'datasets', 'breakthroughs', 'machine', 'learning', 'propelled', 'ai', 'mainstreammachine', 'learning', 'subset', 'ai', 'enables', 'systems', 'learn', 'data', 'improve', 'performance', 'time', 'without', 'explicit', 'programming', 'involves', 'training', 'algorithms', 'large', 'datasets', 'recognize', 'patterns', 'make', 'predictions', 'particularly', 'influential', 'technique', 'deep', 'learning', 'uses', 'neural', 'networks', 'modeled', 'human', 'brains', 'interconnected', 'neurons', 'networks', 'multiple', 'layers', 'process', 'data', 'increasing', 'levels', 'abstraction', 'allowing', 'handle', 'complex', 'tasks', 'like', 'image', 'recognition', 'speech', 'synthesis', 'natural', 'language', 'processingone', 'visible', 'applications', 'ai', 'natural', 'language', 'processing', 'nlp', 'focuses', 'enabling', 'computers', 'understand', 'interpret', 'generate', 'human', 'language', 'voice', 'assistants', 'like', 'siri', 'alexa', 'advanced', 'translation', 'tools', 'chatbots', 'nlp', 'become', 'integral', 'part', 'daily', 'lives', 'large', 'language', 'models', 'developed', 'openai', 'organizations', 'produce', 'humanlike', 'text', 'answer', 'questions', 'even', 'compose', 'poetry', 'codeai', 'also', 'made', 'remarkable', 'strides', 'computer', 'vision', 'systems', 'identify', 'objects', 'images', 'recognize', 'faces', 'even', 'detect', 'emotions', 'technologies', 'power', 'everything', 'social', 'media', 'photo', 'tagging', 'autonomous', 'vehicles', 'selfdriving', 'cars', 'example', 'use', 'aipowered', 'perception', 'systems', 'detect', 'pedestrians', 'traffic', 'signs', 'obstacles', 'making', 'realtime', 'decisions', 'navigate', 'safelyanother', 'important', 'area', 'ai', 'research', 'reinforcement', 'learning', 'systems', 'learn', 'interacting', 'environment', 'receiving', 'feedback', 'form', 'rewards', 'penalties', 'approach', 'used', 'train', 'ai', 'play', 'complex', 'games', 'like', 'chess', 'go', 'video', 'games', 'starcraft', 'reinforcement', 'learning', 'also', 'applied', 'robotics', 'robots', 'learn', 'manipulate', 'objects', 'navigate', 'unfamiliar', 'spacesdespite', 'achievements', 'ai', 'without', 'challenges', 'bias', 'fairness', 'become', 'major', 'concerns', 'ai', 'systems', 'inherit', 'amplify', 'biases', 'present', 'training', 'data', 'instance', 'facial', 'recognition', 'systems', 'shown', 'disparities', 'accuracy', 'across', 'different', 'demographic', 'groups', 'raising', 'ethical', 'social', 'questions', 'researchers', 'policymakers', 'actively', 'working', 'develop', 'guidelines', 'standards', 'ensure', 'ai', 'transparent', 'fair', 'accountableethical', 'considerations', 'extend', 'beyond', 'bias', 'increasing', 'use', 'ai', 'decisionmaking', 'p ...

# %%
stem=PorterStemmer()
stem=[stem.stem(i) for i in removed]
print(stem)
# Out:
# ['artifici', 'intellig', 'often', 'abbrevi', 'ai', 'becom', 'one', 'signific', 'technolog', 'develop', '21st', 'centuri', 'core', 'ai', 'refer', 'abil', 'machin', 'mimic', 'replic', 'human', 'cognit', 'function', 'learn', 'reason', 'problemsolv', 'percept', 'languag', 'understand', 'field', 'root', 'comput', 'scienc', 'mathemat', 'cognit', 'scienc', 'blend', 'disciplin', 'creat', 'system', 'process', 'inform', 'make', 'decis', 'independentlyth', 'journey', 'ai', 'began', 'decad', 'ago', 'earli', 'pioneer', 'like', 'alan', 'ture', 'john', 'mccarthi', 'lay', 'theoret', 'groundwork', 'ture', 'famou', 'questioncan', 'machin', 'thinkspark', 'debat', 'continu', 'day', 'mccarthi', 'often', 'call', 'father', 'ai', 'coin', 'term', 'artifici', 'intellig', '1956', 'dartmouth', 'confer', 'research', 'imagin', 'futur', 'machin', 'could', 'simul', 'human', 'intelligencesinc', 'earli', 'day', 'ai', 'evolv', 'dramat', 'field', 'seen', 'period', 'rapid', 'progress', 'signific', 'setback', 'known', 'ai', 'winter', 'interest', 'fund', 'wane', 'due', 'unmet', 'expect', 'howev', 'advent', 'power', 'comput', 'access', 'massiv', 'dataset', 'breakthrough', 'machin', 'learn', 'propel', 'ai', 'mainstreammachin', 'learn', 'subset', 'ai', 'enabl', 'system', 'learn', 'data', 'improv', 'perform', 'time', 'without', 'explicit', 'program', 'involv', 'train', 'algorithm', 'larg', 'dataset', 'recogn', 'pattern', 'make', 'predict', 'particularli', 'influenti', 'techniqu', 'deep', 'learn', 'use', 'neural', 'network', 'model', 'human', 'brain', 'interconnect', 'neuron', 'network', 'multipl', 'layer', 'process', 'data', 'increas', 'level', 'abstract', 'allow', 'handl', 'complex', 'task', 'like', 'imag', 'recognit', 'speech', 'synthesi', 'natur', 'languag', 'processingon', 'visibl', 'applic', 'ai', 'natur', 'languag', 'process', 'nlp', 'focus', 'enabl', 'comput', 'understand', 'interpret', 'gener', 'human', 'languag', 'voic', 'assist', 'like', 'siri', 'alexa', 'advanc', 'translat', 'tool', 'chatbot', 'nlp', 'becom', 'integr', 'part', 'daili', 'live', 'larg', 'languag', 'model', 'develop', 'openai', 'organ', 'produc', 'humanlik', 'text', 'answer', 'question', 'even', 'compos', 'poetri', 'codeai', 'also', 'made', 'remark', 'stride', 'comput', 'vision', 'system', 'identifi', 'object', 'imag', 'recogn', 'face', 'even', 'detect', 'emot', 'technolog', 'power', 'everyth', 'social', 'media', 'photo', 'tag', 'autonom', 'vehicl', 'selfdriv', 'car', 'exampl', 'use', 'aipow', 'percept', 'system', 'detect', 'pedestrian', 'traffic', 'sign', 'obstacl', 'make', 'realtim', 'decis', 'navig', 'safelyanoth', 'import', 'area', 'ai', 'research', 'reinforc', 'learn', 'system', 'learn', 'interact', 'environ', 'receiv', 'feedback', 'form', 'reward', 'penalti', 'approach', 'use', 'train', 'ai', 'play', 'complex', 'game', 'like', 'chess', 'go', 'video', 'game', 'starcraft', 'reinforc', 'learn', 'also', 'appli', 'robot', 'robot', 'learn', 'manipul', 'object', 'navig', 'unfamiliar', 'spacesdespit', 'achiev', 'ai', 'without', 'challeng', 'bia', 'fair', 'becom', 'major', 'concern', 'ai', 'system', 'inherit', 'amplifi', 'bias', 'present', 'train', 'data', 'instanc', 'facial', 'recognit', 'system', 'shown', 'dispar', 'accuraci', 'across', 'differ', 'demograph', 'group', 'rais', 'ethic', 'social', 'question', 'research', 'policymak', 'activ', 'work', 'develop', 'guidelin', 'standard', 'ensur', 'ai', 'transpar', 'fair', 'accountableeth', 'consider', 'extend', 'beyond', 'bia', 'increas', 'use', 'ai', 'decisionmak', 'process', 'hire', 'crimin', 'justic', 'spark', 'debat', 'potenti', 'unintend', 'consequ', 'expert', 'advoc', 'explain', 'ai', 'xai', 'seek', 'make', 'ai', 'decisionmak', 'process', 'understand', 'human', 'transpar', 'interpret', 'crucial', 'build', 'trust', 'ai', 'systemsth', 'potenti', 'impact', 'ai', 'employ', 'anoth', 'topic', 'intens', 'discuss', 'ai', 'autom', 'repetit', 'danger', 'task', 'lead', 'increas', 'product', 'safeti', 'also', 'pose', 'challeng', 'worker', 'whose', 'job', 'm ...

# %%
lamma=WordNetLemmatizer()
lamma=[lamma.lemmatize(i)for i in removed]

# %%
print(lamma)
# Out:
# ['artificial', 'intelligence', 'often', 'abbreviated', 'ai', 'become', 'one', 'significant', 'technological', 'development', '21st', 'century', 'core', 'ai', 'refers', 'ability', 'machine', 'mimic', 'replicate', 'human', 'cognitive', 'function', 'learning', 'reasoning', 'problemsolving', 'perception', 'language', 'understanding', 'field', 'root', 'computer', 'science', 'mathematics', 'cognitive', 'science', 'blending', 'discipline', 'create', 'system', 'process', 'information', 'make', 'decision', 'independentlythe', 'journey', 'ai', 'began', 'decade', 'ago', 'early', 'pioneer', 'like', 'alan', 'turing', 'john', 'mccarthy', 'laying', 'theoretical', 'groundwork', 'turing', 'famous', 'questioncan', 'machine', 'thinksparked', 'debate', 'continue', 'day', 'mccarthy', 'often', 'called', 'father', 'ai', 'coined', 'term', 'artificial', 'intelligence', '1956', 'dartmouth', 'conference', 'researcher', 'imagined', 'future', 'machine', 'could', 'simulate', 'human', 'intelligencesince', 'early', 'day', 'ai', 'evolved', 'dramatically', 'field', 'seen', 'period', 'rapid', 'progress', 'significant', 'setback', 'known', 'ai', 'winter', 'interest', 'funding', 'waned', 'due', 'unmet', 'expectation', 'however', 'advent', 'powerful', 'computer', 'access', 'massive', 'datasets', 'breakthrough', 'machine', 'learning', 'propelled', 'ai', 'mainstreammachine', 'learning', 'subset', 'ai', 'enables', 'system', 'learn', 'data', 'improve', 'performance', 'time', 'without', 'explicit', 'programming', 'involves', 'training', 'algorithm', 'large', 'datasets', 'recognize', 'pattern', 'make', 'prediction', 'particularly', 'influential', 'technique', 'deep', 'learning', 'us', 'neural', 'network', 'modeled', 'human', 'brain', 'interconnected', 'neuron', 'network', 'multiple', 'layer', 'process', 'data', 'increasing', 'level', 'abstraction', 'allowing', 'handle', 'complex', 'task', 'like', 'image', 'recognition', 'speech', 'synthesis', 'natural', 'language', 'processingone', 'visible', 'application', 'ai', 'natural', 'language', 'processing', 'nlp', 'focus', 'enabling', 'computer', 'understand', 'interpret', 'generate', 'human', 'language', 'voice', 'assistant', 'like', 'siri', 'alexa', 'advanced', 'translation', 'tool', 'chatbots', 'nlp', 'become', 'integral', 'part', 'daily', 'life', 'large', 'language', 'model', 'developed', 'openai', 'organization', 'produce', 'humanlike', 'text', 'answer', 'question', 'even', 'compose', 'poetry', 'codeai', 'also', 'made', 'remarkable', 'stride', 'computer', 'vision', 'system', 'identify', 'object', 'image', 'recognize', 'face', 'even', 'detect', 'emotion', 'technology', 'power', 'everything', 'social', 'medium', 'photo', 'tagging', 'autonomous', 'vehicle', 'selfdriving', 'car', 'example', 'use', 'aipowered', 'perception', 'system', 'detect', 'pedestrian', 'traffic', 'sign', 'obstacle', 'making', 'realtime', 'decision', 'navigate', 'safelyanother', 'important', 'area', 'ai', 'research', 'reinforcement', 'learning', 'system', 'learn', 'interacting', 'environment', 'receiving', 'feedback', 'form', 'reward', 'penalty', 'approach', 'used', 'train', 'ai', 'play', 'complex', 'game', 'like', 'chess', 'go', 'video', 'game', 'starcraft', 'reinforcement', 'learning', 'also', 'applied', 'robotics', 'robot', 'learn', 'manipulate', 'object', 'navigate', 'unfamiliar', 'spacesdespite', 'achievement', 'ai', 'without', 'challenge', 'bias', 'fairness', 'become', 'major', 'concern', 'ai', 'system', 'inherit', 'amplify', 'bias', 'present', 'training', 'data', 'instance', 'facial', 'recognition', 'system', 'shown', 'disparity', 'accuracy', 'across', 'different', 'demographic', 'group', 'raising', 'ethical', 'social', 'question', 'researcher', 'policymakers', 'actively', 'working', 'develop', 'guideline', 'standard', 'ensure', 'ai', 'transparent', 'fair', 'accountableethical', 'consideration', 'extend', 'beyond', 'bias', 'increasing', 'use', 'ai', 'decisionmaking', 'process', 'hiring', 'criminal', 'justice', 'sparked', 'debate', 'potential', 'unin ...

# %%
from collections import Counter
values=Counter(lamma)
top_10=values.most_common(20)
top_10
# Out:
# [('ai', 35),
#  ('system', 8),
#  ('human', 7),
#  ('learning', 6),
#  ('language', 6),
#  ('researcher', 6),
#  ('machine', 5),
#  ('also', 5),
#  ('computer', 4),
#  ('process', 4),
#  ('make', 4),
#  ('like', 4),
#  ('future', 4),
#  ('learn', 4),
#  ('data', 4),
#  ('tool', 4),
#  ('model', 4),
#  ('use', 4),
#  ('challenge', 4),
#  ('bias', 4)]

# %%
import matplotlib.pyplot as plt
elements, counts = zip(*top_10)

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(elements, counts, color='skyblue')
plt.xlabel('Elements')
plt.ylabel('Counts')
plt.title('Top 20 Most Common Elements')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.stem import PorterStemmer,WordNetLemmatizer
from nltk.corpus import stopwords

# %%
data="""1. Generative AI models like GPT-4 can generate human-like text, write code, and answer questions.
2. OpenAI’s ChatGPT has revolutionized conversational interfaces in various industries.
3. Stable Diffusion and DALL·E are popular generative models used for creating images from text prompts.
4. The ethics of generative AI include concerns about misinformation, deepfakes, and copyright issues.
5. Researchers are exploring ways to detect AI-generated content using watermarking and forensic analysis.
6. Generative AI is transforming marketing by enabling automated ad copywriting and content personalization.
7. In the gaming industry, AI is being used to generate dynamic environments, dialogues, and game narratives.
8. Music generation using models like Jukebox has opened new possibilities for AI-assisted creativity.
9. While generative AI boosts productivity, it also raises challenges in job displacement and bias replication.
10. Companies are integrating AI co-pilots into productivity tools like Word, Excel, and Notion.
11. Generative models require vast computational resources and large datasets for pretraining.
12. Fine-tuning LLMs on domain-specific data can yield powerful task-specific agents.
13. Open-source alternatives like Mistral, LLaMA, and Mixtral offer competitive performance at lower cost.
14. There is a growing debate about regulating generative AI to ensure ethical and responsible deployment.
15. Some artists argue that generative AI models trained on their work violate intellectual property rights."""

# %%
data=data.lower()
data
# Out:
# '1. generative ai models like gpt-4 can generate human-like text, write code, and answer questions.\n2. openai’s chatgpt has revolutionized conversational interfaces in various industries.\n3. stable diffusion and dall·e are popular generative models used for creating images from text prompts.\n4. the ethics of generative ai include concerns about misinformation, deepfakes, and copyright issues.\n5. researchers are exploring ways to detect ai-generated content using watermarking and forensic analysis.\n6. generative ai is transforming marketing by enabling automated ad copywriting and content personalization.\n7. in the gaming industry, ai is being used to generate dynamic environments, dialogues, and game narratives.\n8. music generation using models like jukebox has opened new possibilities for ai-assisted creativity.\n9. while generative ai boosts productivity, it also raises challenges in job displacement and bias replication.\n10. companies are integrating ai co-pilots into productivity tools like word, excel, and notion.\n11. generative models require vast computational resources and large datasets for pretraining.\n12. fine-tuning llms on domain-specific data can yield powerful task-specific agents.\n13. open-source alternatives like mistral, llama, and mixtral offer competitive performance at lower cost.\n14. there is a growing debate about regulating generative ai to ensure ethical and responsible deployment.\n15. some artists argue that generative ai models trained on their work violate intellectual property rights.'

# %%
import re
clean=re.sub("[^a-z ]","",data)

# %%
clean
# Out:
# ' generative ai models like gpt can generate humanlike text write code and answer questions openais chatgpt has revolutionized conversational interfaces in various industries stable diffusion and dalle are popular generative models used for creating images from text prompts the ethics of generative ai include concerns about misinformation deepfakes and copyright issues researchers are exploring ways to detect aigenerated content using watermarking and forensic analysis generative ai is transforming marketing by enabling automated ad copywriting and content personalization in the gaming industry ai is being used to generate dynamic environments dialogues and game narratives music generation using models like jukebox has opened new possibilities for aiassisted creativity while generative ai boosts productivity it also raises challenges in job displacement and bias replication companies are integrating ai copilots into productivity tools like word excel and notion generative models require vast computational resources and large datasets for pretraining finetuning llms on domainspecific data can yield powerful taskspecific agents opensource alternatives like mistral llama and mixtral offer competitive performance at lower cost there is a growing debate about regulating generative ai to ensure ethical and responsible deployment some artists argue that generative ai models trained on their work violate intellectual property rights'

# %%
token=word_tokenize(clean)
print(token)
# Out:
# ['generative', 'ai', 'models', 'like', 'gpt', 'can', 'generate', 'humanlike', 'text', 'write', 'code', 'and', 'answer', 'questions', 'openais', 'chatgpt', 'has', 'revolutionized', 'conversational', 'interfaces', 'in', 'various', 'industries', 'stable', 'diffusion', 'and', 'dalle', 'are', 'popular', 'generative', 'models', 'used', 'for', 'creating', 'images', 'from', 'text', 'prompts', 'the', 'ethics', 'of', 'generative', 'ai', 'include', 'concerns', 'about', 'misinformation', 'deepfakes', 'and', 'copyright', 'issues', 'researchers', 'are', 'exploring', 'ways', 'to', 'detect', 'aigenerated', 'content', 'using', 'watermarking', 'and', 'forensic', 'analysis', 'generative', 'ai', 'is', 'transforming', 'marketing', 'by', 'enabling', 'automated', 'ad', 'copywriting', 'and', 'content', 'personalization', 'in', 'the', 'gaming', 'industry', 'ai', 'is', 'being', 'used', 'to', 'generate', 'dynamic', 'environments', 'dialogues', 'and', 'game', 'narratives', 'music', 'generation', 'using', 'models', 'like', 'jukebox', 'has', 'opened', 'new', 'possibilities', 'for', 'aiassisted', 'creativity', 'while', 'generative', 'ai', 'boosts', 'productivity', 'it', 'also', 'raises', 'challenges', 'in', 'job', 'displacement', 'and', 'bias', 'replication', 'companies', 'are', 'integrating', 'ai', 'copilots', 'into', 'productivity', 'tools', 'like', 'word', 'excel', 'and', 'notion', 'generative', 'models', 'require', 'vast', 'computational', 'resources', 'and', 'large', 'datasets', 'for', 'pretraining', 'finetuning', 'llms', 'on', 'domainspecific', 'data', 'can', 'yield', 'powerful', 'taskspecific', 'agents', 'opensource', 'alternatives', 'like', 'mistral', 'llama', 'and', 'mixtral', 'offer', 'competitive', 'performance', 'at', 'lower', 'cost', 'there', 'is', 'a', 'growing', 'debate', 'about', 'regulating', 'generative', 'ai', 'to', 'ensure', 'ethical', 'and', 'responsible', 'deployment', 'some', 'artists', 'argue', 'that', 'generative', 'ai', 'models', 'trained', 'on', 'their', 'work', 'violate', 'intellectual', 'property', 'rights']

# %%
stop_words=stopwords.words("english")
print(stop_words)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %%
remover=[i for i in token if i not in stop_words]
print(remover)
# Out:
# ['generative', 'ai', 'models', 'like', 'gpt', 'generate', 'humanlike', 'text', 'write', 'code', 'answer', 'questions', 'openais', 'chatgpt', 'revolutionized', 'conversational', 'interfaces', 'various', 'industries', 'stable', 'diffusion', 'dalle', 'popular', 'generative', 'models', 'used', 'creating', 'images', 'text', 'prompts', 'ethics', 'generative', 'ai', 'include', 'concerns', 'misinformation', 'deepfakes', 'copyright', 'issues', 'researchers', 'exploring', 'ways', 'detect', 'aigenerated', 'content', 'using', 'watermarking', 'forensic', 'analysis', 'generative', 'ai', 'transforming', 'marketing', 'enabling', 'automated', 'ad', 'copywriting', 'content', 'personalization', 'gaming', 'industry', 'ai', 'used', 'generate', 'dynamic', 'environments', 'dialogues', 'game', 'narratives', 'music', 'generation', 'using', 'models', 'like', 'jukebox', 'opened', 'new', 'possibilities', 'aiassisted', 'creativity', 'generative', 'ai', 'boosts', 'productivity', 'also', 'raises', 'challenges', 'job', 'displacement', 'bias', 'replication', 'companies', 'integrating', 'ai', 'copilots', 'productivity', 'tools', 'like', 'word', 'excel', 'notion', 'generative', 'models', 'require', 'vast', 'computational', 'resources', 'large', 'datasets', 'pretraining', 'finetuning', 'llms', 'domainspecific', 'data', 'yield', 'powerful', 'taskspecific', 'agents', 'opensource', 'alternatives', 'like', 'mistral', 'llama', 'mixtral', 'offer', 'competitive', 'performance', 'lower', 'cost', 'growing', 'debate', 'regulating', 'generative', 'ai', 'ensure', 'ethical', 'responsible', 'deployment', 'artists', 'argue', 'generative', 'ai', 'models', 'trained', 'work', 'violate', 'intellectual', 'property', 'rights']

# %%
lemma=WordNetLemmatizer()
words=[lemma.lemmatize(i)for i in remover]

# %%
print(words[0:10])
# Out:
# ['generative', 'ai', 'model', 'like', 'gpt', 'generate', 'humanlike', 'text', 'write', 'code']
