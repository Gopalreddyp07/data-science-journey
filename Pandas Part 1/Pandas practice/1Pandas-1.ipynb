# %% [markdown]
# ### 📌 1. Data Creation & Importing
# pd.DataFrame(data, columns=[...]) → Creates a DataFrame from a dictionary, list, or NumPy array.
#
# pd.Series(data, index=[...]) → Creates a Pandas Series (1D labeled array).
#
# pd.read_csv('file.csv') → Reads a CSV file into a DataFrame.
#
# pd.read_excel('file.xlsx', sheet_name='Sheet1') → Reads an Excel file.
#
# pd.read_json('file.json') → Reads a JSON file.
#
# pd.read_sql(query, connection) → Reads data from a SQL database.
#
# ### 📌 2. Basic DataFrame Operations
# df.head(n=5) → Returns the first n rows.
#
# df.tail(n=5) → Returns the last n rows.
#
# df.info() → Displays information about the DataFrame.
#
# df.describe() → Provides summary statistics.
#
# df.shape → Returns the dimensions of the DataFrame.
#
# df.columns → Lists all column names.
#
# df.dtypes → Displays data types of columns.
#
# ### 📌 3. Selection & Filtering
# df['column_name'] → Selects a single column.
#
# df[['column1', 'column2']] → Selects multiple columns.
#
# df.iloc[2, 3] → Selects rows/columns by position (index-based).
#
# df.loc[2, 'col'] → Selects rows/columns by label.
#
# df[df['Salary'] > 50000] → Filters rows based on conditions.
#
# df.query("Salary > 50000") → Queries data using string conditions.
#
# ### 📌 4. Data Cleaning & Handling Missing Values
# df.dropna() → Drops rows with missing values.
#
# df.fillna(value) → Replaces missing values with a specified value.
#
# df.isna() → Checks for missing values (returns True/False).
#
# df.duplicated() → Checks for duplicate rows.
#
# df.drop_duplicates() → Removes duplicate rows.
#
# ### 📌 5. Data Transformation
# df['col'].apply(func) → Applies a function to a column.
#
# df['col'].map(lambda x: x*2) → Maps a function element-wise.
#
# df['col'].replace(old, new) → Replaces specific values.
#
# df.rename(columns={'old': 'new'}) → Renames columns.
#
# df['col'].astype('int') → Converts data types.
#
# ### 📌 6. Sorting & Ordering
# df.sort_values(by='col', ascending=False) → Sorts by column values.
#
# df.sort_index(ascending=False) → Sorts by index.
#
# ### 📌 7. Aggregation & Grouping
# df.groupby('col').mean() → Groups data by column and aggregates.
#
# df.pivot(index='col1', columns='col2', values='col3') → Reshapes data without aggregation.
#
# df.pivot_table(values='col', index='col1', aggfunc='sum') → Aggregates and reshapes data.
#
# df['col'].value_counts() → Counts unique values.
#
# ### 📌 8. Merging & Joining
# pd.concat([df1, df2], axis=0) → Combines DataFrames vertically or horizontally.
#
# df1.merge(df2, on='col', how='inner') → Merges DataFrames on a key column.
#
# df1.join(df2, on='key') → Joins DataFrames based on the index.
#
# ### 📌 9. Window Functions
# df['col'].rolling(3).mean() → Computes moving averages.
#
# df['col'].expanding().sum() → Expanding window calculation.
#
# df['col'].cumsum() → Cumulative sum.
#
# df['col'].cumprod() → Cumulative product.
#
# ### 📌 10. Exporting Data
# df.to_csv('file.csv', index=False) → Saves DataFrame to a CSV file.
#
# df.to_excel('file.xlsx', sheet_name='Sheet1') → Saves DataFrame to an Excel file.
#
# df.to_json('file.json') → Saves DataFrame as a JSON file.
#
# df.to_sql('table_name', connection, if_exists='replace') → Saves DataFrame to a SQL table.

# %% [markdown]
# Case Study 1

# %% [markdown]
# Functions That Modify In Place (inplace=True Available)
# ✅ drop(), fillna(), replace(), rename(), drop_duplicates(), reset_index(), sort_values()
#
# Functions That NEVER Modify In Place (Always Return New Object)
# ❌ apply(), map(), groupby(), pivot_table(), merge(), concat(), astype()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data_employee={ 'employee_id':np.arange(1,101),
                'Age':np.random.randint(25,62,size=100),
                'Basic Pay':np.random.randint(15600,67100,size=100),
                'No of Clients':np.random.randint(1,1000,size=100),
                'Years of Service':np.random.randint(0,41,size=100),
                'Performance Score':np.random.randint(0,2,size=100)
              }

#print(type(data_employee))
df=pd.DataFrame(data_employee,columns=['employee_id','Age','Basic Pay','No of Clients','Years of Service','Performance Score'])            

#print(type(df))
df
# Out:
#     employee_id  Age  Basic Pay  No of Clients  Years of Service  \
# 0             1   54      45205            420                38
# 1             2   25      54219            388                35
# 2             3   58      60365            745                25
# 3             4   54      59893            458                27
# 4             5   28      19805            836                 6
# ..          ...  ...        ...            ...               ...
# 95           96   47      51592             85                30
# 96           97   33      17178            957                36
# 97           98   52      45421            893                 4
# 98           99   32      47869            501                12
# 99          100   47      54310            888                 7
#
#     Performance Score
# 0                   0
# 1                   1
# 2                   1
# 3                   1
# 4                   0
# ..                ...
# ...

# %%
df.to_csv("random.csv")

# %%
df=pd.read_csv("random.csv")
df
# Out:
#     Unnamed: 0  employee_id  Age  Basic Pay  No of Clients  Years of Service  \
# 0            0            1   54      45205            420                38
# 1            1            2   25      54219            388                35
# 2            2            3   58      60365            745                25
# 3            3            4   54      59893            458                27
# 4            4            5   28      19805            836                 6
# ..         ...          ...  ...        ...            ...               ...
# 95          95           96   47      51592             85                30
# 96          96           97   33      17178            957                36
# 97          97           98   52      45421            893                 4
# 98          98           99   32      47869            501                12
# 99          99          100   47      54310            888                 7
#
#     Performance Score
# ...

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.head(5)
# Out:
#    employee_id  Age  Basic Pay  No of Clients  Years of Service  \
# 0            1   54      45205            420                38
# 1            2   25      54219            388                35
# 2            3   58      60365            745                25
# 3            4   54      59893            458                27
# 4            5   28      19805            836                 6
#
#    Performance Score
# 0                  0
# 1                  1
# 2                  1
# 3                  1
# 4                  0

# %%
df["Mean"]=df[["Age","Years of Service"]].mean(axis=1)

# %%
df
# Out:
#     employee_id  Age  Basic Pay  No of Clients  Years of Service  \
# 0             1   54      45205            420                38
# 1             2   25      54219            388                35
# 2             3   58      60365            745                25
# 3             4   54      59893            458                27
# 4             5   28      19805            836                 6
# ..          ...  ...        ...            ...               ...
# 95           96   47      51592             85                30
# 96           97   33      17178            957                36
# 97           98   52      45421            893                 4
# 98           99   32      47869            501                12
# 99          100   47      54310            888                 7
#
#     Performance Score  Mean
# 0                   0  46.0
# 1                   1  30.0
# 2                   1  41.5
# 3                   1  40.5
# 4                   0  17.0
# ...

# %%
df.loc[1:5,"Age":"Years of Service"]
# Out:
#    Age  Basic Pay  No of Clients  Years of Service
# 1   25      54219            388                35
# 2   58      60365            745                25
# 3   54      59893            458                27
# 4   28      19805            836                 6
# 5   37      23740            132                 0

# %%
df.iloc[0:5,0:2]
# Out:
#    employee_id  Age
# 0            1   54
# 1            2   25
# 2            3   58
# 3            4   54
# 4            5   28

# %%
plt.fig(figsize=(8,6))
plt.bar(df["Age"],df["Basic Pay"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 plt.fig(figsize=(8,6))
#       2 plt.bar(df["Age"],df["Basic Pay"])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'fig'

# %% [markdown]
# Working with the titanic data set

# %%
from IPython.display import Image
Image("Untitled.jpg")

# %%
import numpy as np
import pandas as pd

# %%
dfs=pd.read_csv("titanic.csv")

# %%
dfs.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dfs.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
dfs.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dfs.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
dfs.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dfs.shape
# Out:
# (891, 12)

# %%
dfs["Survived"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
dfs[""].isna()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
dfs["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
dfs.describe(include="object")
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
def sum(x):
    return x+100
dfs["Sum"]=dfs["Fare"].apply(sum)

# %%
dfs
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dfs["Mean"]=dfs[["Sum","Fare"]].apply(lambda x:x.mean(),axis=1)

# %%
dfs.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked       Sum      Mean
# 0      0         A/5 21171   7.2500   NaN        S  107.2500   57.2500
# 1      0          PC 17599  71.2833   C85        C  171.2833  121.2833
# 2      0  STON/O2. 3101282   7.9250   NaN        S  107.9250   57.9250
# ...

# %%
Male=dfs[dfs["Sex"]=="male"]

# %%
Male
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked       Sum  \
# ...

# %%
dfs["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
dfs["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
dfs["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
dfs.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Sum', 'Mean'],
#       dtype='object')

# %%
dfs.values
# Out:
# array([[1, 0, 3, ..., 'S', 107.25, 57.25],
#        [2, 1, 1, ..., 'C', 171.2833, 121.2833],
#        [3, 1, 3, ..., 'S', 107.925, 57.925],
#        ...,
#        [889, 0, 3, ..., 'S', 123.45, 73.45],
#        [890, 1, 1, ..., 'C', 130.0, 80.0],
#        [891, 0, 3, ..., 'Q', 107.75, 57.75]], dtype=object)

# %%
dfs[(dfs["Pclass"]==2)|(dfs["Pclass"]==3)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
dfs.groupby(["Sex","Pclass"])["Embarked"].size()
# Out:
# Sex     Pclass
# female  1          94
#         2          76
#         3         144
# male    1         122
#         2         108
#         3         347
# Name: Embarked, dtype: int64

# %%
dfs["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
dfs.sort_values(by="Age",inplace=True)

# %%
dfs.reset_index(drop=True,inplace=True)

# %%
dfs.loc[450:455,"Age"]
# Out:
# 450    33.0
# 451    33.0
# 452    33.0
# 453    33.0
# 454    33.0
# 455    33.0
# Name: Age, dtype: float64

# %%
# for tuples in Male.itertuples(name="Passenger"):
#     print(tuples)

# %%
# for rows in Male.iterrows():
#     print(rows)

# %%
dfs["Age"].fillna(dfs["Age"].mean(),inplace=True)
# Out:
# C:\Users\gopal\AppData\Local\Temp\ipykernel_18884\2563392297.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfs["Age"].fillna(dfs["Age"].mean(),inplace=True)

# %%
dfs["Age"]=dfs["Age"].astype(int)

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Sum          891 non-null    float64
#  13  Mean         891 non-null    float64
# dtypes: float64(3), int32(1), int64(5), object(5)
# memory usage: 94.1+ KB

# %%
dfs[(890//2):(890//2+10)]
# Out:
#      PassengerId  Survived  Pclass  \
# 445           71         0       2
# 446          123         0       2
# 447          124         1       2
# 448           86         1       3
# 449          286         0       3
# 450          131         0       3
# 451          507         1       2
# 452          760         1       1
# 453          753         0       3
# 454          473         1       2
#
#                                                   Name     Sex  Age  SibSp  \
# 445                         Jenkin, Mr. Stephen Curnow    male   32      0
# 446                               Nasser, Mr. Nicholas    male   32      1
# 447                                Webber, Miss. Susan  female   32      0
# 448  Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female   33      3
# 449                                Stankovic, Mr. Ivan    male   33      0
# 450                               Drazenoic, Mr. Jozef    male   33      0
# ...

# %%
dfs.sort_values("Age",inplace=True)

# %%
dfs
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0            804         1       3       Thomas, Master. Assad Alexander
# 1            756         1       2             Hamalainen, Master. Viljo
# 2            645         1       3                Baclini, Miss. Eugenie
# 3            470         1       3         Baclini, Miss. Helene Barbara
# 4             79         1       2         Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                   ...
# 709          117         0       3                  Connors, Mr. Patrick
# 710          494         0       1               Artagaveytia, Mr. Ramon
# 711           97         0       1             Goldschmidt, Mr. George B
# 712          852         0       3                   Svensson, Mr. Johan
# 713          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#         Sex  Age  SibSp  Parch    Ticket     Fare Cabin Embarked       Sum  \
# ...

# %%
dfs.reset_index(drop=True,inplace=True)

# %%
dfs
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0            804         1       3           Thomas, Master. Assad Alexander
# 1            756         1       2                 Hamalainen, Master. Viljo
# 2            645         1       3                    Baclini, Miss. Eugenie
# 3            470         1       3             Baclini, Miss. Helene Barbara
# 4             79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 886          860         0       3                          Razi, Mr. Raihed
# 887          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 888          869         0       3               van Melkebeke, Mr. Philemon
# 889          879         0       3                        Laleff, Mr. Kristo
# 890          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
group=dfs.groupby(["Survived","Sex","Pclass"])["Sex"].count()

# %%
group
# Out:
# Survived  Sex     Pclass
# 0         female  1           3
#                   2           6
#                   3          72
#           male    1          77
#                   2          91
#                   3         300
# 1         female  1          91
#                   2          70
#                   3          72
#           male    1          45
#                   2          17
#                   3          47
# Name: Sex, dtype: int64

# %%
group.plot(kind="bar")
# Out:
# <Axes: xlabel='Survived,Sex,Pclass'>

# %%
group.plot(kind="pie")
# Out:
# <Axes: ylabel='Sex'>

# %%
import pandas as pd
df = pd.read_csv("weather.csv")
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
melted = pd.melt(df, id_vars=["day"], var_name='city', value_name='temperature')
melted
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47
